# %%
import requests as rq
from bs4 import BeautifulSoup
import re
from openpyxl import Workbook
from selenium import webdriver

# %%
def get_html(url):
    _html = ""
    resp = rq.get(url)
    if resp.status_code == 200:
        _html = resp.text
        return _html
    else:
        return 0

# %%
def get_datgel(base_url):
    file = open('test.txt', 'a', encoding='utf-8')
    review_list = []
    count = 1
    driver = webdriver.Chrome()
    driver.get(base_url)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    #reviews = soup.find('div', {'class':'commentListInner'}).find_all("div", re.compile("comment"))
    reviews = soup.find_all('span', {'class':'cmt'})
    #print(reviews)
    
    for review in reviews:
        review_list.append(review.get_text().strip())
        print(count, "\b번 댓글 : ", review_list[-1])
        print("\n")
        count += 1
        file.write(review_list[-1] + "\n--------------------------------------------------\n")
    file.close()
    return review_list

# %%
base_url = 'http://www.ilbe.com/index.php?mid=ilbe&'

html = get_html(base_url)
soup = BeautifulSoup(html, 'html.parser')
area = soup.find_all("a", {"class": "subject"})
for index in area:
    _url = index["href"]
    _url = 'http://www.ilbe.com' + _url
    _text = index.text.split(".")
    print(_url)
    print(_text[0])
# Out:
# http://www.ilbe.com/view/10568992181
# 신규 회원 및 기존 1레벨 제한 적용 관련 설명충 등판한다
# http://www.ilbe.com/view/11072878792
# 일베운영 및 문의게시판 운영에 대해 공지하겠습니다
# http://www.ilbe.com/view/11196217818
# 민주당 실시간 표정
# http://www.ilbe.com/view/11196211332
# 조국 콘서트 진행자 민주당 ㅋㅋㅋㅋ
# http://www.ilbe.com/view/11196212660
# ㅋㅋㅋ ㅆㅂ 조국 기자회견 결론 나왔다
# http://www.ilbe.com/view/11196207202
# 두 차선 잡고 가는 오토바이
# http://www.ilbe.com/view/11196216810
# 조국
# http://www.ilbe.com/view/11196214697
# 장학금을 반납 신청했대ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# http://www.ilbe.com/view/11196204158
# 우리나라가 절대 전쟁 못하는 이유
# http://www.ilbe.com/view/11196213948
# 자한당이 청문회 보이콧한 이유가 딱 나오자너 ㅋㅋㅋㅋ
# http://www.ilbe.com/view/11196211951
# LG디스플레이에서 불화수소 국산화 성공했다네
# http://www.ilbe.com/view/11196206853
# 한국 최초의 공원
# http://www.ilbe.com/view/11196208636
# 고등영어 1타강사
# http://www.ilbe.com/view/11196212812
# 만독불침 수련하는 디시인
# http://www.ilbe.com/view/11196196084
# 흑인이랑 전라도가 동급인 이유 (팩트)
# http://www.ilbe.com/view/11196200523
# 일본 AV男배우의 김치창녀 정복기
# http://www.ilbe.com/view/11196208122
# 함박도 사건이 왤케 조용한지 이해가 안감
# http://www.ilbe.com/view/11196208709
# 일본 중년 남자들 사진 모음
# http://www.ilbe.com/view/11196204060
# 너무 청렴결백했던 이승만대통령 아들
# http://www.ilbe.com/view/11196192164
# 울집 댕댕이
# http://www.ilbe.com/view/11196200010
# 오늘부터 바뀐 새번호판
# http://www.ilbe.com/view/11196205178
# 여자친구 부모님한테 인사드리고 온 뒤 부터 여자친구한테 정 떨어진다
# http://www.ilbe.com/view/11196201119
# 울등도 입국 거부당한 일본인 여친
# http://www.ilbe.com/view/11196205181
# 현 부산시장 오거돈 레전드
# http://www.ilbe.com/view/11196201366
# 이효리가 애를 안낳는 이유
# http://www.ilbe.com/view/11196201997
# 19) 실시간 일베 걸게
# http://www.ilbe.com/view/11196201297
# 면접가서 정치성향 밝혔다
# http://www.ilbe.com/view/11196197705
# 맨해튼에서 만남
# http://www.ilbe.com/view/11196199228
# 흑인 자지에 대한 오해
# http://www.ilbe.com/view/11196115299
# 구석기시대 진행중인 원숭이
# http://www.ilbe.com/view/11196192151
# 요즘 유튜브 좆같은 광고
# http://www.ilbe.com/view/11196197105
# 일 매출 20만윈 냉면집 주방보조 일상

# %%
login_url = 'http://www.ilbe.com/'

user = '아이디'
password = '비밀번호'

# requests.session 메서드는 해당 reqeusts를 사용하는 동안 cookie를 header에 유지하도록 하여
# 세션이 필요한 HTTP 요청에 사용됩니다.
session = rq.session()

params = dict()
params['m_id'] = user
params['m_passwd'] = password

session = rq.session()
# javascrit(jQuery) 코드를 분석해보니, 결국 login_proc.php 를 m_id 와 m_passwd 값과 함께
# POST로 호출하기 때문에 다음과 같이 requests.session.post() 메서드를 활용하였습니다.
# 실제코드: <form name="frm"  id="frm"  action="#" method="post">
res = session.post(login_url, data = params) 

# 응답코드가 200 즉, OK가 아닌 경우 에러를 발생시키는 메서드입니다.
res.raise_for_status() 

print(res)
# Out:
# <Response [200]>

# %%
base_url = 'http://www.ilbe.com/list/ilbe?'
page_path = 'page=%d'
end_url = '&listStyle=list'

page = 1
count = 0
review_list = []

#몇페이지 크롤링할지 1이면 첫페이지만
while page <= 1:
    sub_path = page_path%(page)
    html = get_html(base_url + sub_path + end_url)
    
    if(html == 0) :
        break
    
    soup = BeautifulSoup(html, 'html.parser')
    area = soup.find_all("a", {"class": "subject"})
    
    for index in area:
        count += 1;
        _url = index["href"]
        _url = 'http://www.ilbe.com' + _url
        _text = index.text.split(".")
        #print(count, "\b번 제목 : ", _text[0])
        
        review_list.append(get_datgel(_url))
        
    page += 1
    
print(review_list)
# Out:
# 1번 댓글 :  보지털
#
#
# 2번 댓글 :  지잠털
#
#
# 3번 댓글 :  777777777777777222777777777777777
# 777777777288888888888887777777777
# 777777778888888888888888877777777
# 777777788888054494088888887777777
# 777777788877777277208888887777777
# 777777788871884745488888887777777
# 777777778072482748525488887777777
# 777777777227242728817588877777777
# 777777777722052548882088877777777
# 777777777777722298888888880777777
# 777777777720852150888888888888027
# 777758888888877545277888888888888
# 798888888888872277778888888888888
# 588888888888874880788888888888888
# 888888888888278897888888888888888
# 888888888888818808888888888888888
# 888888888888872888888888888888888
# 888888888888882728888888888888888
# 888888888888887788888888888888888
#
#
# 4번 댓글 :  경험치가 안오른다 빨리 수정해라
#
#
# 5번 댓글 :  언제 고렙 되노?얼마나 걸리노 보통?
#
#
# 6번 댓글 :  낄낄낄
#
#
# 7번 댓글 :  나도 고랩되고 싶다
#
#
# 8번 댓글 :  출석체크라는게 글을 올려야되는거노?
#
#
# 9번 댓글 :  ㅁㅍ
#
#
# 10번 댓글 :  씨발놈아 나도 ㅁㅈㅎ 누르고싶다괜히 본캐 처 지워서 씨발
#
#
# 11번 댓글 :  난 몇년동안 2랩이냐 왜
#
#
# 12번 댓글 :  일베 한번 보내면 3렙 되겠네
#
#
# 13번 댓글 :  경험치타임좀 만들어라렙이 너무안오른다
#
#
# 14번 댓글 :  경험치 부스터 캐시 300무현
#
#
# 15번 댓글 :  하루에 200개를 몇날며칠 계속해서 만드는놈도 대단하다
#
# 그쯤되면 그건 이미 열정 정도도 아니고 광기네
#
#
# 16번 댓글 :  ㅂㅇㄹ
#
#
# 17번 댓글 :  오ㅑ시발자꾸 이게클릭되냐
#
#
# 18번 댓글 :  와 씨발 운매새끼들 드디어 일하네 좆같은련들아 함대줘라
#
#
# 19번 댓글 :  섹스
#
#
# 20번 댓글 :  쎅스
#
#
# 21번 댓글 :  씨발 렙2짜리 아이디 지웠다가다시 렙2만들라니까 좆같이 힘드노 개같은년아 2렙으로 올려라 내꺼
#
#
# 22번 댓글 :  추천 이 안되네 나 0렙이냐? 가입일이 몇년 인데 ㅋㅋ
#
#
# 23번 댓글 :  나 로그인만으로 4렙담
#
#
# 24번 댓글 :  ㅡㅡヽ、_ノㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅤ
# ㅤㅤㅤ 'ｰ '
# ㅤㅤㅤㅤㅤＯ
# ㅤㅤㅤㅤㅤㅤo
# ㅤㅤㅤㅤㅤㅤ 。
# ………………_„-,-~''~''':::'':::':::::''::::''~
# ………._,-'':::::::::::::::::::::::::::::::::::::::''-„
# ………..,-'::::::::::::::::::::::::::::::::::::::::::::::|
# ………,-'::::::::::::„:„„-~-~--'~-'~--~-~--~-
# ……..,'::::::::::,~'': : : : : : : : : : : : : : : : : : '-|
# ……..|::::::::,-': : : : : : : : - -~''''¯¯''-„: : : : :\
# ……..|::::::::|: : : : : : : : : _„„--~'''''~-„: : : : '|
# ……..'|:::::::,': : : : : : :_„„-: : : : : : : : ~--„_: |'
# ………|::::::|: : : „--~~'''~~''''''''-„…_..„~''''''''''''¯|
# ………|:::::,':_„„-|: : :_„---~: :|''¯¯''''|: ~---„_: ||
# ……..,~-,_/'': : : |: :(_ o__): : |: : : :|:(_o__): \..|
# ……../,'-,: : : : : ''-,_______,-'': :. : : : ''-„__ ___ |
# ……..\: :|: : : : : : : : : : : : : :„: : : : :-,: : : : : : \
# ………',:': : : : : : : : : : : : :,-'__: : : :_',: : : : ;: ,'
# ……….'-,-': : : : : :___„-: : :'': : ¯''~~'': ': : ~--|'
# ………….|: ,: : : : : : : : : : : : : : : : : : : : : :: : :|
# ………….'|: \: : : : : : : : -,„_„„-~~--~--„_: :: |
# …………..|: \: : : : : : : : : : : :-------~: : : : : |
# …………..|: :''-,: : : : : : : : : : : : : : : : : : : : :|
# …………..',: : :''-, : : : : : : : : : : : : : : : : :: ,'
# ……………| : : : : : : : : :_ : : : : : : : : : : ,-'
# ……………|: : : : : : : : : : '''~--------~''
# ……….„-''. '-,_: : : : : : : : : : : : : : : : : ,'
# ……,-''. . . . . '''~-„_: : : : : : : : : : : : :,-'''-„
#
#
# 25번 댓글 :  이거 진구야?
#
#
# 26번 댓글 :  나도 빨리 고렙되고 싶다
#
#
# 27번 댓글 :  ㅅㅂ 글올리고 싶어도 못올리잖아
#
#
# 28번 댓글 :  1렙이 왜 추천 ㅁㅈㅎ 못하냐 완전오바아니냐
#
#
# 29번 댓글 :  ㅇㅂ
#
#
# 30번 댓글 :  숙지완료했다~
#
#
# 31번 댓글 :  ㅅㄱ많다
#
#
# 32번 댓글 :  ㅁ
#
#
# 33번 댓글 :  숙지
#
#
# 34번 댓글 :  ㅅㄱ많음
#
#
# 35번 댓글 :  이새끼 퇴사안함?
#
#
# 36번 댓글 :  엌ㅋㅋㅋㅋ 백수 ㅊㅋ한다 엌ㅋㅋㅋㅋ 공중제비돈다이기야 엌ㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 37번 댓글 :  소금쟁이랑 설명충 무슨관계?
#
#
# 38번 댓글 :  어쩐지
#
#
# 39번 댓글 :  일베 가자 ㅋㅋㅋㅋㅋ
#
#
# 40번 댓글 :  근데 게시글은 어떻게 올림. 존나 찾아봐도 없네
#
#
# 41번 댓글 :  네
#
#
# 42번 댓글 :  잉여력 어떻게 키우노?
#
#
# 43번 댓글 :  아엠어 보이
#
#
# 44번 댓글 :  3.0 민주화 폭탄대기중 필승!
#
#
# 45번 댓글 :  ㅎㅎ
#
#
# 46번 댓글 :  ㅇㅂ
#
#
# 47번 댓글 :  ㅋㅋㅋㅋㅋㅋㄱㅅ
#
#
# 1번 댓글 :  떡감 어떻냐?
#
# 너랑 한번 느껴 보고싶다.
#
#
# 2번 댓글 :  들딱인데 글을 어캐 올리는지 설명좀 해주라...............
#
#
# 3번 댓글 :  고생해
#
#
# 4번 댓글 :  좆까 씨발년아
#
#
# 5번 댓글 :  일간베스트저장소 베너 직원상시모집 보고 나도 취직하고 싶은 욕망이 퐉퐉 생겼는데 운영자게이야 나 취직못하냐 이기?
#
#
# 6번 댓글 :  근데 시발 비번 찾기왜 안되냐?
# 갑자기 로그인풀렸는데 비번생각안나서 이메일찾기했는데7일만에 오냐? 미쳤노 ㅡㅡ
#
#
# 7번 댓글 :  나는 왜 수 개월째 추천이 안되노???
#
#
# 8번 댓글 :  와 진짜 망했구나
#
#
# 9번 댓글 :  유지 빨통 함 까라 장기적인 수익 내가 보장한다
#
#
# 10번 댓글 :  ㅇㅂ가 적자면 오유같은 다른 사이트는 어떻게 운영되노
#
#
# 11번 댓글 :  광고
#
#
# 12번 댓글 :  직무유기 ㅆㅅㅌㅊ
#
#
# 13번 댓글 :  천조국처럼 프리미엄 레벨 서비스를 해서 한달에 2-3천원내면 광고같은거 없고 플러스로 다크모드같으거 너서 데탑에도 하약/회섹 말고 검저 스킨같은거 기능 추가해서 클린ㅇㅂ하게되는 서비스를 하던 유료서비스를 생각해맨날 광고로만 돈처먹을려고 하지말고 ㅇㅂ충들한테 직접돈벌고 기능좀 업그래이드하고 그리고 ㅇㅂ 인터패이스좀 업하자 ㅅㅂ 요새는 모니터 다 16:9이고 나같은 소수는 21:9 32:9가는데 ㅅㅂ ㅇㅂ사이트 아직도 무슨 90년데 스타일임
#
#
# 14번 댓글 :  너네 왜 그런식이냐맘에 안든다 좀 똑바로 좀 해라 일을 그렇게 밖에 못하냐
#
#
# 15번 댓글 :  틀
#
#
# 16번 댓글 :  빨...
#
#
# 17번 댓글 :  나새야 일베얼마주고 삿노? 확시원하게 까봐라...투자도 받노???
#
#
# 18번 댓글 :  존댓말 씹소름.... 형 왜이래? 무섭게
#
#
# 19번 댓글 :  너무 정게로 운지시킨다  유머로 냅둘만한데  노무하는거 아니노?  운마ㅆㅅㅋ야
#
#
# 20번 댓글 :  하여간 수고많다
#
# 개소리 하는것들은 분탕이다생각하고
#
# 걍 신경꺼라
#
#
# 21번 댓글 :  다시끄럽고 유지 썅년아 보밍하지말고 분탕이나 잡아라.  분탕은 모른척하고 분탕 고발하는 게이를 벤하는게 일베 맞냐? 일베의 본질은 우파 정치사이트가 맞어. 근데 일베 망하라고 개소리 찍찍하는 분탕들 왜 안잡는건데?운마가 홍어년 아니면 왜 이러는지 이해 불가함.
#
#
# 22번 댓글 :  그리고 모든 커뮤니티 몰락의 중심엔 보지가 있었다. 그래서 일베가 보밍을 철저하게 단속한건데 뭐 운바가 보밍하고 유튭을 개설한다고? 이거 홍어 아니고는 나올수 없는 발상이라고 ㅎ. 진심 홍어면 정정당당하게 홍밍아웃하던지. 그래야 일베의 정체성을 게이들이 오해를 안하지 ㅎ
#
#
# 23번 댓글 :  정게틀딱들 기사 캡쳐 한장에 일베가거나 기사 한줄찍으로 일베가는거 좀 제발 막아라 무슨 일베글 십중팔구가 다 기사펌이냐
#
#
# 24번 댓글 :  웃흥
#
#
# 25번 댓글 :  성능좋은 노무현 응디~
#
#
# 26번 댓글 :  늬기미 시바, 정베는 왜? 머땀시 가동을중지했냐,개시발 운마 세끼들아
#
#
# 27번 댓글 :  노무현
#
#
# 28번 댓글 :  나 매일 이글 보면서 딸친다.ㅁㅌㅊ?
#
#
# 29번 댓글 :  곧 떠나야해 너희는,,, 개인적으로 운영이 미흡함
#
#
# 1번 댓글 :  모두가 다 아는 걸 난 모른다고 답하니ㅋㅋㅋ
#
#
# 2번 댓글 :  박주민은 원래 24/7 365일 표정이 썩었어 쟤 웃는 거 보려면 돈다발 쌓아놓거나,  김정은 보여줘야돼
#
#
# 3번 댓글 :  ㅋㅋㅋㅋ
#
#
# 4번 댓글 :  ㅋㅋㅋㅋㅋㅋ
#
#
# 5번 댓글 :  말 존나 못함 ㅋㅋ 이미 나온 자료도 다 부정 ㅋ
#
#
# 6번 댓글 :  여자 표정이 거의 부카니스탄 급인데?인민의 표정
#
#
# 7번 댓글 :  뭐라노 쟤들표정원래 썩창임
#
#
# 8번 댓글 :  재들도 속으로는 씨발할꺼야 ㅋㅋㅋ근데 지내 대장 문재앙이 시키니 어쩔수 없는거지 ㅋㅋ
#
#
# 9번 댓글 :  진짜 국민들을 개우습게 보는듯그냥 이제 이 정권은 민주당과 같이 소멸시켜야 함저런부정부패비리범으로 법무부장관에 앉힌다고행안부 장관에 연쇄살인마 유영철...교욱부 장관에 조두순 앉혀라 시발 새키들아
#
#
# 10번 댓글 :  인민군마냥 주렁주렁 달고 다니는 개새끼 아닌가
#
#
# 1번 댓글 :  윗허벅지 엉덩이 살랑살랑... 개꼴
#
#
# 2번 댓글 :  나연이 잘 흔드노
#
#
# 3번 댓글 :  짤 개좆같은 년 올려서 ㅁㅈㅎ
#
#
# 4번 댓글 :  연합뉴스 두명임
#
#
# 5번 댓글 :  차라리 저런 쇼하고 바로 임명되는게 낫다그래야 개 돼지들이 정신 좀 차리지
#
#
# 1번 댓글 :  조국은 언제 넘기냐?
#
#
# 2번 댓글 :  깜빵으로
#
#
# 3번 댓글 :  내가 미안! 졸업식 때 봐!
#
#
# 4번 댓글 :  틀딱새끼들 한동안 잠잠하더니 또 시작이네
#
#
# 5번 댓글 :  보나마나 저거 쇼한다음에 이제 언론에서도 조국이 말한대로 놀아나게 되어있음 조국이 한말을 근거로 맞다고 조국편에 서서 기사 내고 맘충년들 또 댓글 조작 좆나게 한걸야
#
#
# 6번 댓글 :  기자간담회 듣으니, 솔깃하다 그럴수도 잇겟다 생각든다 이렇게 개돼지 한 마리가 느는거같다
#
#
# 1번 댓글 :  조금 덜 착해진듯 ㅋ
#
#
# 2번 댓글 :  안 죽었잖아
#
#
# 3번 댓글 :  병신 ㅋㅋㅋㅋㅋㅋ
#
#
# 4번 댓글 :  저짓전
#
#
# 5번 댓글 :  저런 허세는 경상도 사람인듯
#
#
# 6번 댓글 :  ㅎㅎ 너가 전라도인건 알겠다
#
#
# 7번 댓글 :
#
#
# 8번 댓글 :  에휴 딱 보니 짱개구만
#
#
# 9번 댓글 :  오토바이충 좆같은 점 지 꼴리는데로 운전함 어떨 때는 차선 하나 차지하면서 가다가 자기 급하면 인도나 차 사이사이로 존나 지나댕김 제발 뒤졌으면
#
#
# 10번 댓글 :  전방을 포기한다.
#
#
# 11번 댓글 :  아 좆같은 좆토바이새끼들그리고 개좆같은 국개새끼들
#
#
# 12번 댓글 :  각기 ㅇㅂ근데 저거보다 더 웃긴 건 고딩인가 그 새끼 각기하다가 혼자 넘어져서 바지 찢어진 거 ㅋㅋ
#
#
# 13번 댓글 :  끊임 없는 찰과상
#
#
# 14번 댓글 :  마음 만은 밀어버리고 싶은 충동이 가득차 있음 실행을 못 할뿐이지 ㅅㅂ
#
#
# 15번 댓글 :  사지가토막낫어야햄는ㄷㆍㅋ
#
#
# 16번 댓글 :  오토바이 타는게이야 질문좀 받아줘오토바이타고 차선변경할때 깜빡이 말고 따로 수신호로 이쪽으로 갈꺼니가 좀 양보해주셈 이런것도 있음?
#
#
# 17번 댓글 :  운전초보나 보지들은 그런수신호 못알아들어서 절대로하면안댐 ㅇㅇ
#
#
# 18번 댓글 :  무적권 깜박이 켜고 안전거리 확보하고 들어가는게 최선임?
#
#
# 19번 댓글 :  왜 당연한걸 물어보냐
#
#
# 20번 댓글 :  도산대로네
#
#
# 21번 댓글 :  찐따새끼들 학창시절 오타바이타는 일진한테 처맞은 기억폭력이 떠올라서 라이더만 보면 과민반응하며 부들거리네 ㅋㅋㅋㅋ
#
#
# 22번 댓글 :  착해지지않아서 ㅁㅈㅎ
#
#
# 23번 댓글 :  안착해져서 ㅁㅈㅎ.
#
#
# 24번 댓글 :  뒷쪽 사람들 견제하느라 앞 못 보고 꼬라박네.
#
#
# 25번 댓글 :  일본인데? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 26번 댓글 :  흠.. 착하게하려면 더강력해야돼...
#
#
# 27번 댓글 :  병신 착해지기나하지
#
#
# 1번 댓글 :  하나 더 있잖아 ㅋㅋㅋ 제도의 문제다
#
#
# 2번 댓글 :  딱 예상한대로임. 기자들도 날카로운 질문도 없음.
#
#
# 3번 댓글 :  ㄹㅇ기레기들
#
#
# 4번 댓글 :  조국이 몰랐다는 말이 100프로 사실이라고 가정해도, 딸 문제는 딸이 당시에 미성년자였기 떄문에 부모의 책임에서 벗어나기 힘들고, 부인 사모펀드 문제는 부부는 경제 공동체이기 때문에 책임론에서 벗어나기 힘들고, 웅동학원 문제는 이사를 했기 때문에 책임론에서 벗어나기 힘듬. 조국 본인의 유무죄는 모르겠지만, 최소한 부인이나 동생을 포함해서 측근들 구속되거나 감옥가게 생겼는데, 법무부 장관을 하겠다는 것 자체가 코메디임.
#
#
# 5번 댓글 :  내말이
#
#
# 6번 댓글 :  특검 가야할듯 내가했다는 증거있어? 증거있냐고? 이 급임
#
#
# 7번 댓글 :  잘 듣고 있습니다잘 알고 있습니다
#
#
# 8번 댓글 :  ㅈㄱㄹ(정게로 일수도, 지게로 일수도 있습니다)
#
#
# 9번 댓글 :  윤석열인 뭐하냐? 오늘도 병든 닭처럼 꾸벅 꾸벅 졸구있냐?
#
#
# 10번 댓글 :  조국 기자회견 보면 윤석열에 대해서는 걱정 안한다는 느낌임
#
#
# 11번 댓글 :  박근혜는 말한마디도 안하고 깜빵서 3년짼데 부처님이노?
#
#
# 12번 댓글 :  그년은 걍 병신년인거고
#
#
# 13번 댓글 :  ㅈㄱㄹ
#
#
# 14번 댓글 :  닭대가리인가보지
#
#
# 15번 댓글 :  셀프 청문회무언가 자꾸 주절거림결론은 없고자기 자신도 속이는 조국의 대단한 쑈.
#
#
# 16번 댓글 :  진짜 사람을 개돼지로 아는새끼다...
#
#
# 17번 댓글 :  뭘 대단해. 계속 말 돌리고 꼬아가며 감성적으로 접근하는구만.. 딱 보지들이 좋아하는 화술이네. 내가 볼때 개돼지들 이거 끝나면 감동의 물을 질질 흘리며 옹호할거다 니미
#
#
# 18번 댓글 :  혁명말고는 답이 없다
#
#
# 19번 댓글 :  묵시적 청탁이지
#
#
# 20번 댓글 :  ㅋㅋㅋㅋ 난 이대로 조국이 임명됬음 좋겟다 ㅋㅋㅋ 이 개돼지나라의 끝이 어딘지 궁금하네 ㅋㅋ
#
#
# 21번 댓글 :  마술사지하지 않아고 알지도 않았는데주변에서 알아서 도와주고 만들어주고 일을 해줬으니마술사지
#
#
# 22번 댓글 :  청문회 중임?
#
#
# 23번 댓글 :  국개들도 개무시 기자들만 모아서 저런간담회하는 이유가있었구만ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 좋겠다 기자들은 개무시당하고있어서ㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 24번 댓글 :  말하는 잘 들어봐라 왁스질만 오지게 하고 본질 흐리고 있다 그게 목적이거든 국민은 개돼지니까
#
#
# 1번 댓글 :  김유정도 살인한 남편 살려내면 무죄됨?
#
#
# 2번 댓글 :  살려내면 살인죄는 아니겠지김유정은 누구냐 근데
#
#
# 3번 댓글 :  ㅋㅋㅋㅋ 그러네
#
#
# 4번 댓글 :  여친인듯
#
#
# 5번 댓글 :  배우,소설가?? 누ㄱ가죽였음?
#
#
# 6번 댓글 :  살려낼 수 있는 기술이 있으면 전 세계적 영웅인데 ㅋ
#
#
# 7번 댓글 :  네크로멘서노?
#
#
# 8번 댓글 :  강간범 좆국 "넣던 자지 도로 빼서 강간 아니다"
#
#
# 9번 댓글 :  야  나도 컴퓨터 2년썻는데 속도 좆나느려서 반납하면 다시 돈 돌려줌??
#
#
# 10번 댓글 :  ㅋㅋㅋㅋㅋ
#
#
# 11번 댓글 :
#
#
# 12번 댓글 :  아니 받아놓고 문제됬을때 반납하면 끝이냐 ㅅㅂ
#
#
# 13번 댓글 :  됐 병신아 국민학교 야간이누
#
#
# 14번 댓글 :  울.....동년배들은.......됬...이다이기....
#
#
# 15번 댓글 :  진짜 어이가 없다 씨발
#
#
# 16번 댓글 :  은행 털어서 돈 불리고 돌려주면 무죄란 소리네이거 괜찮네
#
#
# 17번 댓글 :  비유ㅇㅂ
#
#
# 18번 댓글 :  최고의 비유..
#
#
# 19번 댓글 :  아니 시발 저딴논리면 이재용도 최순실한테 돈낸거 다 돌려주면 끝나는일이네 박근혜도 돈먹은거 다뱉으면 대통령 다시가능 ㅋㅋㅋ
#
#
# 20번 댓글 :  안타깝지만 박근혜 본인은 돈 받은게 없음 ㅋㅋㅋ
#
#
# 21번 댓글 :  ㅇㅇ 나도 박근혜가 돈땜에 깜빵갔다곤 생각안함
# 그냥 좌파들이 주장하는 말 빌렸을 뿐 임
#
# 박근혜가 깜빵간 결정적 이유는 사드배치로 짱깨새키들이 몰아낸거 ㅇㅇ
#
#
# 22번 댓글 :  현역병도 입대영장 반납하면 전역시켜주냐?
#
#
# 23번 댓글 :  오예
#
#
# 24번 댓글 :  무슨 중고나라론도 아니고 ㅋㅋㅋ
#
#
# 25번 댓글 :  은행서 훔친돈 도로갖다노면 죄가업당게
#
#
# 26번 댓글 :  아니 신청만 했대 근데 반납 규정은 없다고...
#
#
# 27번 댓글 :  형법학자라는게기수라는걸 모를리도 없고...이미 범죄기수면 돌려줘도 범죄자되는거지
#
#
# 28번 댓글 :  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 미친새끼들 칼빵놓고 꼬메주면 다 갠찮겠다?
#
#
# 29번 댓글 :  반납신청을 언제했는데
#
#
# 30번 댓글 :  뇌물 걸려도 그냥 반납하면 봐주자이기야ㅋㅋㅋㅋㅋㅋ
#
#
# 31번 댓글 :  도서관에서 책 빌렸냐 ㅋㅋㅋ
#
#
# 32번 댓글 :  칼빻놓고 흉터제거수술해주면 끝이냐?
#
#
# 33번 댓글 :  회사 돈 1억 횡령해서 토토해서 2배 따고 다시 집어넣으면 무죄 ㅇㅈ? ㅋㅋ
#
#
# 34번 댓글 :  캬 칼로 찌르고 다시 뽑았으니까 나는 무죄다 ㅋㅋㅋㅋㅋ
#
#
# 35번 댓글 :  컥...지상 최고의 비유다..이런 재치있는 비유는  60평생 처음 듣는다
#
#
# 36번 댓글 :  대~~단하다... 말이노...  시청자가 병신이노...
#
#
# 37번 댓글 :  부정하게 받았음을 스스로 인정한건가?
#
#
# 38번 댓글 :  3달전에 전라도 홍어마냥 내 뒷통수까고 배신한년 배때지에 칼침놓고 후시딘 발라주면 무죄가 되는건가?
#
#
# 39번 댓글 :  그럼 최순실 돈도 반납하고 다시 빼줘라 ㅋㅋㅋ
# 1번 댓글 :  당나라 군대가 무슨 전쟁을 하냐? 걍 별들고 폼만 잡는 거야
#
#
# 2번 댓글 :  팩트:실제 이세민의 당군은 동아시아 역사상 손꼽히는 강군이었다
#
#
# 3번 댓글 :  이미 함박도넘김
#
#
# 4번 댓글 :  ㄹㅇ 김치년들과 안보불감증 좌빨꼰대들을 내가 총들고 지켜주기 싫다
#
#
# 5번 댓글 :  역사적으로 혼자서 뭘 한적이 없으니
#
#
# 6번 댓글 :  혼자한거 있음ㅋㅋㅋ이성계가 위화도 회군으로 우왕과 최영장군도 죽이고 나라세움ㅋ팀킬오졌다리
#
#
# 7번 댓글 :  다른나라같으면 벌써 폭동일어나고 징병제폐지되거나 월급200은나왔음문재앙같은새끼들이 하나같이 북한은 약하다고 걱정할꺼없다고  급식새끼들선동시켜놔서 진짜인줄아는데 전쟁나면 1:1상황이면 100%패배함.
#
#
# 8번 댓글 :  핵무기안써도 도심지에 화학무기 몇방 터뜨리면 혼란의 도가니가 될듯
#
#
# 9번 댓글 :  그렇게 되게 페미를 퍼트린게 좌빨들임
#
#
# 10번 댓글 :  연평도 포격때백화점을 터니명품만 챙기니축포드립치던게 한국년들임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 11번 댓글 :  안경은 위장하려고 일부러 끼고 잇는거임?
#
#
# 12번 댓글 :  냉전시대 끝나고 소련멸망하고 중국도 산업화 다된마당에절대 전쟁안함 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아직도 전쟁위협하는건 틀딱맞다
#
#
# 13번 댓글 :  군대가면 있던 애국심도 사라짐.
#
#
# 14번 댓글 :  응 군인 대우는 오래전부터 ㅄ이었어 그나마 군사정권때가 나았을뿐 ....솔직히 병역제도 제대로 따져봐라 오래전부터 노예제도였어
#
#
# 15번 댓글 :  절대라는 건 없어
#
#
# 16번 댓글 :  짜장면 한그릇 먹고싶다던지 소망 없슙니꽈?
#
#
# 17번 댓글 :  여기 있숩니다
#
#
# 18번 댓글 :  근데 막상 전쟁하면 잘할수도...?
#
#
# 19번 댓글 :  ㄹㅇ 인생의 가장 좆같은 경험은 군대임ㅅㅂ 모병제로바꿔야함
#
#
# 20번 댓글 :  ㄴㄴ 갔다온사람입장에선 징병 3년이상해야지^^
#
#
# 21번 댓글 :  한국은 자주국방을 절대 불가능함전쟁한지도 오래됏고현역들수준이 개판이라
#
#
# 22번 댓글 :  경외심을 갖기엔 너무 병신같이들 생겼음...
#
#
# 23번 댓글 :  김치보지년들은 지들 가랭이에 노숙자 냄새나는 북괴섀끼들 자지가 들어올 때 아차 싶을 듯
#
#
# 24번 댓글 :  그러니 희생없이 평화도 없다는거임직접 쳐맞고 공산국가되면 비로소 알게됨그치만 막상 그렇게되면 찍소리 못하고 복종하니까 문제
#
#
# 25번 댓글 :  그냥 사회주의 체제로 바뀌면 사회주의 체제에 맞게 살면 되지 뭐  목숨걸고 애써서 나라 지킬 필요 뭐있노
#
#
# 26번 댓글 :  그당시 철없어서 당연히가야한다고 생각한게 후회됨진짜 빠질 구멍을 있었는데 휴... 2년넘는시간을 좃같은트라우마 남기며 보냈음
#
#
# 27번 댓글 :  안타깝노 ㅜㅜ 놀랍게도 정신병원에 자주가는 한남들 중에 과반수가 군생활 하면서 생긴 트라우마를 잊지못해 오는경우가 많다는데 ...
#
#
# 28번 댓글 :  나도 경계선지능인데 왜 뭐가 좋다고 간건지 모르겠다
#
#
# 29번 댓글 :  전쟁이 시작 되면 가장 먼저 안경 보급선을 확보해야 할 듯.  우리나라 군인들은 안경 없으면 전쟁 못할 듯.
#
#
# 30번 댓글 :  애초에 전쟁에 참여하지 않았고 대부분의 남자가 현역복무를 하기 때문에 경외심은 없을 수 있다.다만 학교에서 어렸을때부터 군인에 대한 고마움과 국방의 중요성을 평화타령보다 더 열심히 가르쳐야한다.
#
#
# 31번 댓글 :  말도안된다 서울에 사는 친인척이 몇명인데 남한사람들이 가만히 있을거 같냐
#
#
# 32번 댓글 :  어제 뉴스봤는데 국방부에서 이수지역해제인가뭔가를 했나보더라 근데 양구가서 취재하면서 지역민 인터뷰하는데 세금신고하는데 30~40%줄어들었다는거임 그러면서 국방부에서 시행취소해달라고 하던데 진짜 양심이있는지 되묻고싶더라
#
#
# 33번 댓글 :  막상 전쟁나면 잘할수도있다 09군번인데 연평도 상황터졌을때 전투대기상황뜨고 군장다싸고 대기하는데 분대원끼리 서로 북한새끼들 다죽여버리자 했던 기억이있음
#
#
# 34번 댓글 :  애초에 전쟁을 왜 해야되는데?삼국지시대인지 아냐?ㅋㅋ
#
#
# 35번 댓글 :  미군은 가난한 사람들이랑 양아치 범죄자새키들이 들어가는곳이라는데 진짜냐?
#
#
# 36번 댓글 :  만약 일본하고 전쟁하면 병사 30%는 일본에 바로 투항하거나 협력할듯
#
#
# 37번 댓글 :  군인 스스로도 군대 계율 좆같이 알고 서로를 무시하는데일반 민간인들에게 경외심같은거 바라지도 마라 ㅋㅋ군대가기전에 '군대간다~ 좆같다~ 한국군대 좆같다~' 징징대면서가족 친구 가랭이 붙잡고 지랄이란 지랄은 다떨어놓고막상 군인되서는 지같은 오합지졸 병신군인한테 남들이 경외심 존경심 가져주길 원함 ㅋㅋ
#
#
# 38번 댓글 :  거짓말과 사기의 민족이고 용기가 없는 민족이다미-영 문화권의 공통점이 자유주의와 민주정 기반이면서 상류층이 강하고 용감하다는 것임전쟁 나면 상류층 자제들이 장교로 입대하고 파일럿으로 입대하고 해군 입대해서 목숨 거는 풍토가 자리 잡음그러다보니 피해의식을 주로 공격하는 저열한 사회주의 공산주의 정치 세력이 대세로 자리잡지 못 함상류층이 강하고 목숨을 거니 아래 층에서도 인정하는 거지물론 소수의 기피자들이 있으나 대부분의 상류층은 중하류층보다 강하고 용감함"내가 이런 지위를 누릴 자격이 있음을 보여주겠다"는 의식이 자리잡고 있다고 함자유주의와 용감하고 강한 상류층 - 한국도 이런 풍토가 자리잡도록 해야 미래가 있다중-일-러에 비해서 작은 나라라고 하지만 한국의 인구와 국민소득은 독-프-영에 비해 엄청 떨어지는 게 아님자유주의가 뿌리내리고 용감하고 강한 상류층이 있는 나라라고 가정해 봐라. 한국이 그리 만만한 사이즈가 아님
#
#
# 39번 댓글 :  솔직히 대우도 좆같아 병사로 들어가면 간부(지들은 돈 벌려고 일부러 군인함)새끼들한테 항상 쪼인트 까여 무시당하고 병사들 입장은 좆도 생각 안해줌.간부새끼들이 하는 제일 큰 착각중에 하나가 자기들은 나라 지킬려고 자진해서 군대 들어왔는데 오기 싫은데 억지로 끌려온 병사들은 지들보다 군대에 대한 경외심이나 충성심이 낮다고생각하고 지들보다 신분이 아래라고 생각함ㅋㅋ 또 병사입장에서의 고통,고민 이런것들은 지들에 비하면 쥐좆도 아닌것처럼 여김  이런 개씹당나라군대에서 전쟁나면 잘도 하겠다
#
#
# 40번 댓글 :  예비군도 민방위들도 다들 수준떨어져서ㅋㅋ 미군없인 안됨ㅋㅋ예비군 퇴소기준빡세게 잡기전엔 캠프수준이였고퇴소기준빡세지자 예비군날 35도 이상되기만 바라고있고민방위는 그냥 유급반차날이라 생각하니ㅋㅋ
#
#
# 1번 댓글 :  청문회에서 거짓말해도 법적 처벌한 근거가 없다더라알 지 못 했습니다이제 알았습니다.끝.
#
#
# 2번 댓글 :  씹잘알씹국 잘 알
#
#
# 3번 댓글 :  자한당이 질질 짜면서 감성팔이 할 수 있는 딱좋은 대들보임 이미지가 씹악당이라
#
#
# 4번 댓글 :  내가 잘못한게 있어도 내가 할 일이 있기때문에 법무부장관은꼭 해야겠다 ㅋㅋㅋ
#
#
# 5번 댓글 :  청문회하기로핲의햇다며?
#
#
# 6번 댓글 :  펀드도 조카 회사가 맞는데 회사에서 이미 해명했다라고 하고 끝임 ㅋㅋ말 하는거 보면 검찰조사에 대해서는 걱정을 하고 있지 않다는게 딱 보이네 ㅋㅋㅋㅋ ㅆㅂ
#
#
# 7번 댓글 :  검찰조사중이니 답변을 드릴수가 없다빠졌노
#
#
# 8번 댓글 :  어차피 조국은 임명될거야자한당은 그걸 아니까 쑈는 지들끼리 하라는거지아직도 문재인 실체를 모르는 사람들많네 씨벌
#
#
# 9번 댓글 :  조국 임명하는순간 문재앙도 레임덕가능성있을텐데
#
#
# 10번 댓글 :  문재인 무시하너?
#
# 계럼령 걸어서라도 고려연방제 자기 임기내에 할거임
#
# 조국이는 고려연방제를 위해서 법무부당관 꼭 시켜야 하니까 될거임
#
#
# 11번 댓글 :  그런건 상관도 없음..
#
# 검찰을 동원하면 ㄷ거든..
#
#
# 12번 댓글 :  <<< 닭틀딱들의 목적 >>>연동형 비례제임.선거법 개악을 통하면 한국당은 비례를 1석도 못가져갈 공산이 큼지금 닭틀들이 선동하는게 지역구는 한국당 비례대표는 개한매국당(우공당) 찍으면 된다고 밑밥까는중그 작업을 하려먼 한국당은 무능하다. 대안은 우공당이다!!!  세뇌하려는거임.그러기위해 매일같이 달창들 콜라보로, 한국당 뭐하노 !! 충 대거등판하는거임 이게 그 본질적 이유- 만약 그렇게 진행되면 우파는 영영 패망함. 한국당 자체가 없어질것- 닭틀 새끼들이 빨갱이인 이유가 이거임.
#
#
# 13번 댓글 :  검찰측에서 조사중이라 답변드리기 어렵다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 14번 댓글 :  청문회는 했어야지 병신같이 저걸 날리노그냥 하는게 아니라 존나 물증 가지고 와서 팩트 폭행 날려주고조국 어버버 하게 만들거나,아님 숨겨놓은거 큰거 터트려서 당황하게 만들어야지.이게 뭐냐?문재앙이랑 민주당이 좋다고 하고 청문회도 없이 임명 하겠네ㅋ씨발 야당이란 새끼들이 개병신들만 쳐 모여서씹근혜년이  쳐 뽑아서 그런가.빨리 자유한국당 물갈이 가야함.하는 꼬라지 보니까 총선도 쳐 발리겠다 병신 새끼들ㅉㅉ
#
#
# 15번 댓글 :  한국당은 무능하다.  한국당 뭐하노충 또 등판
#
# 너네 닭틀은 단1도 한거없어 병신아
#
# 이미 한국당은 특검가기로 함  수고링 ^^
#
#
# 16번 댓글 :  청문회 하지 말라 지랄
#
# 이젠 또 청문회 왜 안했냐 지랄
#
# 아주 존나 속편하게 살지? 닭틀딱 빨갱이들 ㅋㅋㅋ
#
#
# 17번 댓글 :  중국에서 6000억 썼는데 안될리가 있겠노
#
#
# 18번 댓글 :  그래도 청문회해서 조리돌림해야 속이라도 시원할텐데이게 뭐하는 짓인지 모르겠다
#
#
# 19번 댓글 :  검찰수사대상 관련은 답변할수 없습니다. 윤석열이랑 짜고치는 한판이제라~~
#
#
# 1번 댓글 :  헬지 스마트폰 한번 쓰면 두번 다시 헬지는 안쓰게 되던데
# 헬지는 조잡하고 잔고장이 심함
#
#
# 2번 댓글 :  이제 모니터 불량률 증가하는 거 아니냐 ㄷㄷ
#
#
# 3번 댓글 :  빨리 주식매입해라 개미들아
#
#
# 4번 댓글 :  님 여기서 질문엘지도 반도체 만드나요? ㅋㅋ엘지디스플레이에서 만든 그게반도체에서 쓰는것과 같은 건가요?
#
#
# 5번 댓글 :  ㅁㅈㅎ왜케많노ㅋㅋ일뽕들ㅂㄷㅂㄷ
#
#
# 6번 댓글 :  북한에 넘길지도 모름.이젠 대놓고
#
#
# 7번 댓글 :  디스플레이는 초고순도 불산 필요없음 문제는 반도체에 필요한 초고순도 불산임
#
#
# 8번 댓글 :  아니 씨발 병신들 많네 외국에서 수입을 안해주는데 만들기만하고 어떻게 팔껀데 씨발 ㅋㅋㅋ 외국에선 일제품으로 안만들면 안산다는데 대안있냐,
#
#
# 9번 댓글 :  갓지가 또 ㅈㅎ
#
#
# 10번 댓글 :  엘지디 저 회사는  적자로 cb 발행하는 수준이면서  저런 짓거리나 하고있으니까  망하지   소형 oled 수율이나 높일 생각부터 해라
#
#
# 11번 댓글 :  쪽빨이새끼들 좆됫놐ㅋ
#
#
# 12번 댓글 :  정신승리 ㅅㄱ
#
#
# 13번 댓글 :  글쓴놈 븅신이네 ㅋㅋ 당연히 뻥이지 저걸믿냐? ㅋㅋ우리나라언론이 팩트로 기사쓰냐? ㅋㅋ
#
#
# 14번 댓글 :  통까흥=과학
#
#
# 15번 댓글 :  화관법, 화평법 손보기 전엔 국산화해 봐야 개털..공장을 지을수가 없는데 생산을 어케하냐?
#
#
# 16번 댓글 :  불화수소를 누가 못만드냐 병신아 순도가 중요한거지 조선놈들은  죽었다 깨나도 트웰브나인 못만듬
#
#
# 17번 댓글 :  퓽신 좆본색기 ㅎㅇ
#
#
# 18번 댓글 :  제조장비도 반도체랑 디스플레이랑 정밀도 차이 크지않냐?
#
#
# 19번 댓글 :  디스플레이에 쓰이는 불화수소하고 반도체하고 쓰이는 것 하고 순도가 다름.반도체에 쓰이는 건 초 고순도라서 빠른 시일내 대체 되는게 불가능함
#
#
# 20번 댓글 :  LCD에 들어가는 불화수소는 5N~7N 짜리고국내중소기업 솔브레인은 일본과 합작회사인데 여기서는 5N까지는 나옴 물론 그마저도 전부 일본소재 받아서 만드는거반도체에 들어가는 불화수소는 12N짜리고아직도 미상의 업계관계자가 씨부리는 기사 보고 좋아하는 새끼들이 진짜 내부의 적이지불과 몇주전에 최태원이 박영선 깔때도 국산꺼 순도 문제 해결도 못하고 있고 아직 실용화도 못하는데 어떻게 국산중소기업꺼쓰냐고 일갈한거 모르노http://biz.chosun.com/site/data/html_dir/2019/07/18/2019071801826.htmlhttp://biz.chosun.com/site/data/html_dir/2019/07/18/2019071801826.htmlhttp://biz.chosun.com/site/data/html_dir/2019/07/18/2019071801826.html국내중소기업은 전부 일본소재 받아서 가공하거나 일본과 합작회사고현시점에서 불화수소 국산꺼는 종류,크기,순도 어느것하나 대기업 입맛에 맞게 나오는거 없음LCD는 그나마 저급 불화수소 쓰니까 5N까지만 써도 상관 없는거고LCD랑 반도체에 들어가는 불화수소 같다고 생각하는 흑우 없지?참고로 8월24일자 오피셜로 삼성에는 국산화TF는 없다고 했고, 공급처를 어떻게 해야 할지 내부고민중이라고 했다.
#
#
# 21번 댓글 :  이렇게  용도 구분도 안하고 퉁쳐서 불산 국산화라고 하면 넘어가서 빨아대는 머가리 썩은 인간이 ㅇㅂ에도 넘쳐나네이러니까 조국이 기자간담회 열어 변명 늘어놓으면 아 그렇구나 하면서또 지지 하는거지병신들
#
#
# 22번 댓글 :  민중은 개돼지고 일베도 민중인데 개돼지가 9할이 넘는 건 거스를 수 없는 노무현이 주도 하는 질서랑께~
#
#
# 23번 댓글 :  6개월 뒤 뉴스헬쥐 디스플레이 2019년 하반기 생산된 제품 대량 리콜통상적인 리콜, 국내산 불화수소 때문은 아냐
#
#
# 24번 댓글 :  자살해라 병신아 ㅋㅋㅋㅋ
#
#
# 25번 댓글 :  국산화 해서 북한 주는건 아니지!?
#
#
# 26번 댓글 :  개소리 ㅋㅋ 한달만에 뚝딱 개발하는걸 그동안 손 놓고 있었다구-???
#
#
# 27번 댓글 :  일베는 친일파가 맞는듯
#
#
# 28번 댓글 :  전라도에 반대하면 친일파냐?
#
# 그럼 친일파 맞아
#
#
# 29번 댓글 :  LG ㅋ
#
#
# 30번 댓글 :  가격은 좀 비쌀듯
#
#
# 31번 댓글 :  순도는? ㅋㅋㅋㅋㅋㅋ
#
#
# 32번 댓글 :  응 그딴거 좆도 아닌 기술이야 좆만아^^
#
#
# 33번 댓글 :  병신새끼 ㅁㅈㅎ
#
#
# 34번 댓글 :  ㄹㅇ 댓글보면 믿을새끼가 한명도없네 정치병안걸린사이트없나  다 지하고싶은소리 씨부리고있네 잘 알지도못하는새끼들이
#
#
# 35번 댓글 :  뻥까인지 아닌지 두고 봐야지
#
#
# 36번 댓글 :  마지막 줄 뜬금 없네 ㅋㅋㅋㅋ혹시 국민청원에 노무현 전 대통령 살려달라고 글 쓴 게이냐?
#
#
# 37번 댓글 :  노컷뉴스ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 1번 댓글 :  한국은 앞으로 자유란 두글자를 사용하지 못함
#
#
# 2번 댓글 :  유두는
#
#
# 3번 댓글 :  월미도 놀이기구 왤케 짠해보이냐
#
#
# 4번 댓글 :  옐로우 하우스 생각나네 ㅋㅋ
#
#
# 5번 댓글 :  기념탑밑에 에알리언 쭈그리고 앉아있는듯
#
#
# 6번 댓글 :  ㅇㅂ
#
#
# 7번 댓글 :  저기 전라도 식당이 왤케 많냐 안 맞게
#
#
# 8번 댓글 :  몰랐냐 월미도 뿐 아니라 서해쪽 횟집 어촌계는 전부 전라도가 꿰차고 앉아있다. 소래포구 시흥 안산 오이도 당진 태안 대천 보령...
#
#
# 9번 댓글 :  맥아더장군이 계신 저런 신성한 곳 근처에 전라도가 있는게 맘에 안듦
#
#
# 10번 댓글 :  ㅇㅂ가랏
#
#
# 11번 댓글 :  오륙도전라도횟집은 홍통일체식당이냐
#
#
# 12번 댓글 :  백주년기념탑에서 깡통차기 오지게했다깡통차기 나보다 잘하는새끼 못봄
#
#
# 13번 댓글 :  그것은 너가 혼자 했기 때문에...
#
#
# 14번 댓글 :  1월달에 월미도 자유공원 갔었는데 여중딩들 디팡 타고 노는거 구경함
#
#
# 15번 댓글 :  인천 = 전라도 2중대
#
#
# 16번 댓글 :  대놓고 음식으로 뒷통수치려고 만든거자너ㅎㅎ
#
#
# 17번 댓글 :  ㅇㅂ
#
#
# 18번 댓글 :  ㅇㅂ
#
#
# 19번 댓글 :  만화 짱에서 애색기들 쌈질하던 공원이네
#
#
# 20번 댓글 :  나 놀러 갔을때는 개량한복 입은 늘근이새끼들이 동상 철거하라고 시위하던데
#
#
# 21번 댓글 :  월미도 바이킹은 딴게 무서운게아니라 안전바가 흑인 부랄마냥 존나 덜컹거려서 저거타다 즉석에서 노짱따라갈것 같음
#
#
# 22번 댓글 :  식당이름에 대놓고 전라도박노ㄷㄷㄷㄷ
#
#
# 23번 댓글 :  어딜가나 즐라도
#
#
# 24번 댓글 :  월미도 어렸을때 추억이 많은데 내가 작년 제작년에 인천 10 몇년만에 갔는데 혼자 월미도 가봤자 재미없고 할 수 있는거 없을까봐 못가봄...
#
#
# 25번 댓글 :  맥아더장군 좀 멋진듯...한미수교100주년 조형물도 괜찮네. 잘 봤음.
#
#
# 26번 댓글 :  틀딱들 진짜...  사진 망치게 뭐하는짓이냐?
#
#
# 27번 댓글 :
#
#
# 1번 댓글 :  고추보집물말고 기억나는거없음 ㅅㄱ
#
#
# 2번 댓글 :  노슨식이 1타 강사다이기야!!!
#
#
# 3번 댓글 :  고추집보물 아니였노?
#
#
# 4번 댓글 :  로즈리 생각하며 들어옴 나 틀딱이냐??
#
#
# 1번 댓글 :  리얼 인간 해독제노
#
#
# 2번 댓글 :  어떻게 그게 가능하노 좆나 신기하네
#
# 유튜브 검색간다
#
#
# 3번 댓글 :  스티브 러드윈 검색 ㄱㄱ
#
#
# 4번 댓글 :  저새끼 나중에 빡촌가서 노콘했는데 창녀디짐
#
#
# 5번 댓글 :  시밬ㅋㅋㅋㅋ
#
#
# 6번 댓글 :  ㅋㅋㅋ 장수말벌 그자체노
#
#
# 7번 댓글 :  ㅋㅋㅋㅋㅋㅋㅋㅋ조읏나 웃기네
#
#
# 8번 댓글 :  저거 맞음 계속 맞으면 무뎌짐 처음에는 간지러워서 잠못자는데계속 맞으면 간지러운것도 무감각해짐봉침 내가 많이 맞아봤다
#
#
# 9번 댓글 :  미친놈
#
#
# 10번 댓글 :  국딩때 벌초갔다가 말벌한테 무릎쏘였었는데 어떤느낌이냐면 쏘인 부분은 조오나 따갑고 화끈거리는데 주변은 물파스원액 처바른듯 시원하면서 화끈거렸음 .. 벌써 30년정도 지났는데 아직도 생생하노..
#
#
# 11번 댓글 :
#
#
# 12번 댓글 :  ㅈㅈ에다 했으면 커지냐?
#
#
# 13번 댓글 :  ㅈㅈ에는 꿀벌침으로 맞는다
#
# 나야 ㅈㅈ가 커서 안맞아봤지만 주위에 맞아본놈꺼 봤는데
#
# 커졌다고 존나게 좋아하던데
#
# 그 커졌다고 좋아하는게 내꺼보다 작음
#
# 시발 며칠지나니까  원래대로 돌아가더라
#
#
# 14번 댓글 :  원래대로 돌아가면 ㅋㅋㅋ
#
#
# 15번 댓글 :  다큐보니깐 어떤부족중에 살모사독도 저렇게 단련해서 살모사한테 물려도 끄덕없다고하던데. 코브라는 독이 쎄서 물리면 약초먹어야된다함.
#
#
# 16번 댓글 :  어렸을때 놀이터같은데서 꿀벌이나 말벌은 많이 쏘여봤는데 저거 느낌 다르냐?
#
#
# 17번 댓글 :  구라즐
#
#
# 18번 댓글 :  ?? 어렸을때 벌한테 안쏘여봤냐?
#
#
# 19번 댓글 :  신장안좋아질고같은데
#
#
# 20번 댓글 :  친구가 말벌에 목덜미에 3방인가 쏘였는데얼굴이 살짝 부엇고 목덜미는 퉁퉁 붓더라 존나 아프다고 하던데
#
#
# 21번 댓글 :  입에 독이 있노
#
#
# 22번 댓글 :  매져키스트
#
#
# 23번 댓글 :  땡삐한테뒤통수쏘였는데 얼굴털구멍이다부어올라헐크랑똑같아지더라
#
#
# 24번 댓글 :  저거 사이어인 같은거야이겨내면 더 강해지고 면역력 높아지느데 못이겨내면 죽는거지
#
#
# 25번 댓글 :  쏘이는 인증은 없노
#
#
# 26번 댓글 :  진짜 애비개새끼가 벌초하다 말법집쵸서 뺨에 1방쏘였는데 하.,.,., 진짜 시발개새끼 애비 칼로 수셔주고싶을만큼 화끈거리고 뭔가 자꾸 쑤시는느낌듬
#
#
# 27번 댓글 :  아부지랑 사이좋게 지내라
#
#
# 28번 댓글 :  닉값 ㅅㅂㄷㄷ
#
#
# 29번 댓글 :  병신인가 벌이 주딩이로 침 쏘냐 ㅋㅋㅋㅋ
#
#
# 30번 댓글 :  응 신경마비옴
#
#
# 31번 댓글 :  말벌이 쏘기직전에 칼타이밍 잡아서 패링해봐라타격감 쩐다
#
#
# 32번 댓글 :  미친놈이네
#
#
# 33번 댓글 :  어릴 때 무협지 많이 본 놈들 중에 진짜 그거 믿는 빡대가리들 있더라예를들어 경공이라는게 진짜 있어서 계속 수련하면 결국은 풀잎을 밟고 날아다닐 수 있다거나 등등이런 부류는 보통 지잡대도 못 가고 전문대 수준에서 걸러짐
#
#
# 34번 댓글 :  내가그랬음 돌주먹만든다고 바이스에다 주먹물리고 참을수있는고통까지 조임 그짓하다가 주먹아작남
#
#
# 35번 댓글 :  나 퇴근할때 너무 피곤하면 가끔 경공써서 집까지 날아가는데
#
#
# 36번 댓글 :  군대있을때 땅벌한테 손 쏘였는데 손이 두배로 붓더라 ㅆㅂ 주먹대장이라고 ㅈㄴ 놀림받음
#
#
# 37번 댓글 :  난 도라에몽
#
#
# 38번 댓글 :  뱀독 계속 맞아서 항체 만들고 그 피 헌혈해서 혈청 만드는 분도 계신데 이사람도 계속하다가 해독제 만들어질듯
#
#
# 39번 댓글 :  장수인지 뭔지한테 손 함쏘여서 아따거 뭐지? 이랬는데  장수인지 뭔지 존나 큰 벌 위잉 하고 날아가는거  본 후 팔 터질것 같이 아파서 비명 막나옴. 그 자리에서 팔잡고 5분간 뒹굴었음.
#
#
# 40번 댓글 :  짤은 걍 턱에 물리는거구만꽁지침 ㅇㅈ짤도 아니고
#
#
# 41번 댓글 :  내가 어디서 들은 얘기그 강사(이름은 말할 수 없음)가 자기가 어릴 때 깡촌 시골에서차랐는데종종 그랬듯이 아이들 우루루 산등성이 몰려다니고 그랬는데그날도 여럿 우루루 몰려다니다가 어떤 놈인지 벌집을 그만 건드렸다고그래서 모두들 있는 힘 다해 빤스런들 하는데 중간집결지에 와서ㅈ보니 한명이 않보이더란다그게 하필 꼬꼬마들 골목대장 노릇하던 남자애의 꼬마 여동생으로 나이는 6,7살 정도였는데, 다들 빤스런하면서 그 꼬마애를 신경쓰지 못했고 심지어 그 골목대장인 친오빠도 빤스런 때문에 깜빡한 것순간 이거 큰일났다고 직감적으로 느껴서 동네 아저씨들과 같이 현장을 가보니 그 꼬마애가 얼굴 곳곳에 벌떼들이 달라붙어 있고 여기저기 구멍에서 피가 흐르는 등 치명적 상태였고결국 그 가여운 꼬마애는 다음날 사망했다고 그렇게 얘기하더라그러면서 강사분이 여러분, 벌떼 이거 굉장히 무서우니까 정말 주의하세요 그러더만
#
#
# 42번 댓글 :  강사 볼드모트임??
#
#
# 43번 댓글 :  뽕쟁이들도 저러려나?
#
#
# 44번 댓글 :  몇번 계속 쏘이면 과민성 쇼크 오지 않음?
#
#
# 45번 댓글 :  벌은  응디로 침을 쏘는데 절마는 벌 주둥이에 대노?
# 1번 댓글 :  절라도가 급격하게 문제가 생긴 이유는 다른거 없다 원래 그래
#
#
# 2번 댓글 :  도긴개긴 이긴한데 흑인여자가 흑인남자보다 민주당 지지율 10%까지 벌어짐흑인여자만 놓고 본다면 민주당 지지율 95%일걸참고로 미국의 전라도는 "워싱턴 DC" 미국의 수도인걸 알아라여긴 흑인 비율도 그렇지만 백인의 좌파비율도 높아서항상 90% 민주당 지지율 나오는 곳이다.. 다른 50개 주에서 민주당 90% 넘어가는 곳은 거의없는데 DC만 그럼
#
#
# 3번 댓글 :  정게탈출 ㅁㅈㅎ~ 민주화 민주화 민주화 정게로 가라 좀 정게로 가서 쳐 놀아 니네끼리 어휴
#
#
# 4번 댓글 :  ㄹㄷ 까는건 언제나 ㅇㅂ지
#
#
# 5번 댓글 :  경상도
#
#
# 6번 댓글 :  흑인한테 사과해라
#
#
# 7번 댓글 :  와... 흑인보다 더한 놈들이 전라도네.. 어떻게 단일민족 국가에 저런 집단이 생겨났을까?와... 흑인보다 더한 놈들이 전라도네.. 어떻게 단일민족 국가에 저런 집단이 생겨났을까?와... 흑인보다 더한 놈들이 전라도네.. 어떻게 단일민족 국가에 저런 집단이 생겨났을까?
#
#
# 8번 댓글 :  흑인 비하하지 마라실제로 영미권 사는 흑인들 겪어보면 조센1징 수준은 된다전라도보단 훨씬 위고
#
#
# 9번 댓글 :  니가 뭔데?
#
#
# 10번 댓글 :  조선족은??
#
#
# 11번 댓글 :  결정적인게 빠졌네.."잘했든 못했든간에 자기 그룹을 옹호한다.."-그들에겐 영혼이 없다-
#
#
# 12번 댓글 :  보수홍어 안정권 봤다
#
#
# 13번 댓글 :  전라도 이야기는 하지마라 토나올라그런다
#
#
# 14번 댓글 :  전라도 카르텔 없어야 함 그 본부격인 설라도를 개박살내지 않으면 적화시대에서 살아가야 함
#
#
# 15번 댓글 :  제발 서울에서 전라도 사투리 안듣는법좀....요새는 어플도 전라도억양 나와서 미칠거같다
#
#
# 16번 댓글 :  전라도가 흑인보다무서운점은 흑인은 피부색으로 구별이가능하지만 홍어는 통수 당하기전까진 알방법이없다는거다
#
#
# 17번 댓글 :  ㅇㄱㄹㅇ
# 흑인은 그냥 첫인상부터 구별 가능하지만
# 전라도는 아무리 호남형 관상 전라도 사투리 익혀도 흑인만큼 구별해내기 쉽지않아
#
#
# 18번 댓글 :  ㅇㅈ 홍어가 더 무섭네
#
#
# 19번 댓글 :  이인제가 진짜...............  어휴
#
#
# 20번 댓글 :  흑형은 랩이라도 잘하지
#
#
# 21번 댓글 :  좆질도 잘함
#
#
# 22번 댓글 :  흑인 비하해서 ㅁㅈㅎ.
#
#
# 23번 댓글 :  니애미 니그로
#
#
# 24번 댓글 :  홍어 새끼 아니랄까봐
#
# 발끈하는거보소. ㅋㅋ
#
#
# 25번 댓글 :  흑인은  고향세탁은 못하지   홍어보다 월등히  우월함
#
#
# 26번 댓글 :  너 흑인들한테 쫓기겠다어디 씨발 비교할때가 없어서 홍어들하고 비교질이냐고넌 흑형들의 마지막 자존심을 건드렸어
#
#
# 27번 댓글 :  전라도새끼들은 와진짜..한명한명 오함마로줘패면서 개조시키고싶다진짜
#
#
# 1번 댓글 :  난 빠꾸맞은적없는데? 말안통하면 당연히 우리나라도 안받아주지임마
#
#
# 2번 댓글 :  광석이가 모냐 설명좀
#
#
# 3번 댓글 :  유명했던 네임드 남자 AV배우인데 일본인인줄 알았는데 재일교포 였음 한국이름은 이광석
#
#
# 4번 댓글 :  ㄱㅅ왼쪽이 광석?
#
#
# 5번 댓글 :  유광석
#
#
# 6번 댓글 :  게이도 봤노?? 왕가슴 씨발 잘느끼고 개쩜 국산년이였으면 한국말로 느꼈을텐데 그게 아쉽다그리고 역시 현실은 다른게 겐진성님 좆질에 야동처럼 흐느끼며 느끼는 년은 없고 그냥 일반적인 섹스더라
#
#
# 7번 댓글 :  우라(뒷)아가씨 잘 써논거 같은데
#
#
# 8번 댓글 :  ㅇㅇ 틀린거 없음
#
#
# 9번 댓글 :  한참 글 몰입 할려고 하는데 글 마쳐 버리냐... 전형적인 홍어식 리뷰네
#
#
# 10번 댓글 :  아가씨고만
#
#
# 11번 댓글 :  잘써서 ㅇㅂ
#
#
# 12번 댓글 :  ㅇㅂ유튜버 김용호 조국 2차 대박 정보 공개했다 이기http://m.site.naver.com/0tq3o
#
#
# 13번 댓글 :  진짜 2005년도 프루나 시절로 돌아간다면홈쇼핑으로 외장하드를 사서야동을 꽉꽉 담아놓을텐데........
#
#
# 14번 댓글 :  2005년도에 내가 샀던 외장하드 250GB
#
#
# 15번 댓글 :  アガシ=아가씨(시) 맞음
#
#
# 16번 댓글 :  ㅇㅇ 내가 잘못들어서 잘못적음 ㅇㅈ
#
#
# 17번 댓글 :  haja10은 발기부전 + 지루 같더만 ㅇㅇ
#
#
# 18번 댓글 :  마가씨 잼나는데 볼때가 없노
#
#
# 19번 댓글 :  하이퍼매직미러호 한국편은 마지막에 나온 여자가 일본인 페이크였음
#
#
# 20번 댓글 :  ㅇㅇ 한국여자들 만원짜리 돈다발로 젖탱이 까고 만지는건 성공했는데 섹스는 법적으로도 불법으로 불가능하니
# 일본여자를 한국여자로 위장시켜서 떡치는데 어설프고 어눌한 한국말 조금 하면서 한국여자인척 연기하는 일본여자였음
#
#
# 21번 댓글 :  가끔 일본야동에 한국여자라고 나오는것도 일본여자 어설프게ㅡ한국어거나 한국에로배우 데리고 찍는데 후자는 헛좆질인게 딱봐도 보임
#
#
# 22번 댓글 :  한국여자도 에로배우들임
#
#
# 23번 댓글 :  ㅇㅇ 맞음
#
#
# 24번 댓글 :  한국여자 후반에 나온 두명만 에로배우
#
#
# 25번 댓글 :  초반에 검은옷 가슴 큰애도 에로배우임
# 내가 찾아봄
#
#
# 26번 댓글 :  그여자 초반에 안나왔을텐데 딜도 입에물고 오망꼬 거리는 여자자나 나 그여자 누군지 알고있어 그여자말고 한두명더 인터넷 에로쟈키 출신임 그리고 나머지는 그냥 어설픈 일반인 잔챙이들처음엔 무작정 길빵으로 덤비다가 분량이 안나올것을 대비해 섭외한 에로배우 투입! 마무리는 섹스하는 가라김치걸 투입 ㅎㅎ
#
#
# 27번 댓글 :  글에서 아재특유의 구수함이 느껴지노ㅋㅋ
#
#
# 28번 댓글 :  세월이 가면~ ♪
#
#
# 29번 댓글 :  몰카로 찌은 거 아님?
#
#
# 30번 댓글 :  haja10 풍속도 그런 영상도 있었노이것도 폰헙 같은데 있냐?? 검색어 앙망한다.
#
#
# 31번 댓글 :  검색어 : 풍속고발영상 or [ama10.com]
#
#
# 32번 댓글 :  저아재 트젠한테 박히는것도있지 않냐?
#
#
# 33번 댓글 :  부탁입니다. 폰허브 뚫는법좀 가르쳐주세요 형들 kt인데 얼마전까지는 폰허브 앞에 jp븉혀스면 들어가졋는데 이것도 막아놨어 횽들. ㅠㅠ
#
#
# 34번 댓글 :  방금 봤는데 두번째 나온년은 전형적인 김치년이네 표정시발 ㅋㅋ
#
#
# 1번 댓글 :  ? 이북지역도 우리나라 땅인데?
#
#
# 2번 댓글 :  대한민국 헌법에 따르면 북한전체는 공산당이 불법점거하고있는건데? 씨발 빨갱이새끼야?
#
#
# 3번 댓글 :  납북했다는 거 자체가 불법 침입한 거네그리고 불과 1,2년 전까지 무인도 였음.근데 군사분계선에 군사시설은 정상임?광주는?문재인은?
#
#
# 4번 댓글 :  먹고살기 힘들어서 그런데에 관심이 없으니까
#
#
# 5번 댓글 :  원래 북한땅인데?
#
#
# 6번 댓글 :  원래한국땅맞댜
# 엊그젠가 60년대뉴스올린거봐도 한국땅맞고만
#
#
# 7번 댓글 :  아직 시작도 안했어 ㅋㅋㅋㅋㅋㅋ
#
#
# 8번 댓글 :  행정상의 오류라고 몇번을말하냐... 에휴... 유재일유튜브봐라 자세히설명해준다
#
#
# 9번 댓글 :  왜냐하면 문재앙은 중국 간첩이기 때문
#
#
# 10번 댓글 :  왜긴 왜야....언론이 장악당했으니까 그렇지
#
#
# 11번 댓글 :  軍에서 공식적으로 북한땅이라고 인정했으니 그렇지 뭐
#
#
# 12번 댓글 :  팩트: 노짱이 팔아먹은 NLL 이북 섬이라 아무 문재없음
#
#
# 13번 댓글 :  예전에 만주에 간도?인가 거기 땅 되찾아야 한다고 ㅈㄹㅈㄹ 하더니 이번꺼는 논란없누
#
#
# 14번 댓글 :  북좆빨이국ㅇㅂ
#
#
# 1번 댓글 :  ㅁㅂㅎ
#
#
# 2번 댓글 :  저게 어딜봐서 진짜 남자라고 느끼냐? 개븅신새낄세 ㅋㅈㅋ
#
#
# 3번 댓글 :  저게 어딜봐서 진짜 남자라고 느끼냐? 개븅신새낄세 ㅋㅈㅋ
#
#
# 4번 댓글 :  씹치남들 주제파악 못하고 스시녀 운운하는거 ㄹㅇ 갖잖음분위기압도하고 존잘인 스시남들은 가만히잇는데투블럭뿔테충 애즈펌김구안경충들 모여서 깝치는거보면 ㄹㅇ 국가망신
#
#
# 5번 댓글 :  일본 중년 중에서는 이 사람이 가장 멋 있는 듯.  https://thegww.com/wp-content/uploads/2018/07/Hiroshi_Hatake_S1.jpg
#
#
# 6번 댓글 :  중간에 대머리 흰수염할배 아재만 쎄보이는데
#
#
# 7번 댓글 :  2번째짤 오른쪽 남자 멋있네
#
#
# 8번 댓글 :  남자처럼생긴건 한녀가 일본중년남 압승
#
#
# 9번 댓글 :  멸치새끼들만 잔뜩모았노
#
#
# 10번 댓글 :  김치맨 짱깨맨들과는 다른 아우라가있네 레베루가 지가우다
#
#
# 11번 댓글 :  일본에서 본 일본중년. 디자이너 수트에 시계까지 정말 깔끔하게 입고. 매너도 개 좋음. 딱 하나 안좋았던게... 포경수술을 안해서 약간 냄새나더라 ㅜㅜ
#
#
# 12번 댓글 :  그걸 네가 왜 맡아.
#
#
# 13번 댓글 :  전부 다 작고 말라 비틀어졌구만 이건 남자다잼 ㅋㅋㅋㅋ 이 새끼 키 165에 몸무게 50키로 예상함. 그리고 틀딱임.
#
#
# 14번 댓글 :  배달음식네 야식에 소주나 맥주 쳐먹는 뚱때지 조센진 갓본인이 낫지 ㅋㅋㅋㅋㅋ 개소리야 이새기는
#
#
# 15번 댓글 :  조까고 있네 좆같은 틀딱새끼들인데 뭔 시발 일본만 붙으면 뭔가 다 세련되고 좋아보이나 존나 한심하네
#
#
# 16번 댓글 :  저런 볼품없이 삭고 골은 몰골로 후까시 이빠이 잡은거 보고 멋지다고 생각하는 놈이 일단 정상이 아님김C가 이상형인가보네 ㅋ
#
#
# 17번 댓글 :  ㅋㅋㅋㅋㅋㅋㅋㅋ이건남자다잼ㅋㅋㅋㅋㅋㅋㅋ
#
#
# 18번 댓글 :  우리 중년남자 차승원 이병헌 배용준 정우성 장동건이 좆바름 ㅇㅇ
#
#
# 19번 댓글 :  정신나간 일뽕 사이트 다 됐네. 진짜 때려쳐야지
#
#
# 20번 댓글 :  좆같은 시발 일뽕 새끼들 일베 장악했네
#
#
# 21번 댓글 :  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅁㅈㅎ
#
#
# 22번 댓글 :  흡연충 ㅁㅈㅎ
#
#
# 23번 댓글 :  그래도 재넨 취미라도 즐기지
#
#
# 1번 댓글 :  안타까운 청춘이었자.황색언론의 희생자이기도 하고
#
#
# 2번 댓글 :  무조건 팔이 안으로 굽는 미개한 엽전들 중에저런 인물이 있었다는게 믿기지 않는 사실
#
#
# 3번 댓글 :  이승만이 국제정세를 보는 안목은 뛰어났어도 사람 보는 안목은 별로였지
#
#
# 4번 댓글 :  근데 그시절에 사람같은새끼가 몇이나 됐을까?
#
#
# 5번 댓글 :  "이기" 붕 ?야 이기붕좋다~
#
#
# 6번 댓글 :  에휴 병신새끼 ㅉ
#
#
# 7번 댓글 :  자아분열 ㅇㅂ
#
#
# 8번 댓글 :  솔직히 존나 웃겼는데
#
#
# 9번 댓글 :  근데 대가리한방 가슴한방쏴서 죽었다는데 자살이 의심
#
#
# 10번 댓글 :  진짜 ?
#
# 역사적으로보면 그리 오래전 일도 아닌데
#
# 정확한 사건기록이 없노 ?
#
# 우리나라 진짜 미개하네
#
#
# 11번 댓글 :  당시 경호실장이 대통령직을 조선시대 임금처럼 생각해서 이승만이 무너지면 대한민국이 사라질것이라 믿었을수도 있다고함. 그래서 일각에서는 그 경호실장이 이승만을 위해 부통령 가족들을 죽여 여론을 잠재우려 했다는 음모론도 있음.
#
#
# 12번 댓글 :  근데 가슴머리 두발  자살은 가능함. 실제로 내 군대동기도 초소에서  가슴머리  한발씩 쏴서 자살함  k2로 ㅇㅅㅇ
#
#
# 13번 댓글 :  https://www.ilbe.com/view/10855409881
#
# K2로 자살을한다니 상상이안간다
#
#
# 14번 댓글 :  저런분을 조정래 새끼는 희대의 친일파 나라팔아먹은 놈 으로 묘사햇지 그래놓고 어제는 유시민새끼랑 같이 조국 임명해야한다고 개지랄떨더만
#
#
# 15번 댓글 :  와 씨발 부정행위했다고 친애비 죽이는 사람은 대체;;;
#
#
# 16번 댓글 :  자상당한거라고 보는게 합리적인 시각이지 임마
#
#
# 17번 댓글 :  저때 23이면 일제시대때 초중고 나온거 맞제?일본의 자결문화가 남아 있더건가
#
#
# 18번 댓글 :  저때 23이면 소학교 입학할때쯤 해방이었을걸
#
#
# 19번 댓글 :  저런 파이팅이 있어야 지도층이라고 하지누구처럼 사모펀드, 비리입시에 엮이고 언론플레이하고 실종되는 새끼들이 있음
#
#
# 20번 댓글 :  조국이 새끼봐라..깨끗한척 정의로운척..오지게 하더니...돈 욕심도 오짐
#
#
# 21번 댓글 :  나라가 바로설려면 피와희생이 있어야함
#
#
# 22번 댓글 :  우치하 이강석ㄷㄷ
#
#
# 23번 댓글 :  이승만 대통령 양자로 이인수라는 사람도 있던데 양자를 여럿 들인거노?
#
#
# 24번 댓글 :  그냥 미친놈이지. 다른사람도 아니고 아버지가 한건데 아들은 아버지편이어야지. 아버지가 잘했든 못했든
#
#
# 25번 댓글 :  이승만은 친자식 못뒀는데 이강석은 이기붕의 자식이지 이승만의 양자이고아비보단 훨씬 낫지만 굳이 청렴결백이니 뭐니 온갖 미사여구까지 붙일 필요는 없다고 봄
#
#
# 26번 댓글 :  앞뒤다짜르면 이강석이 패륜아처럼 보일 수 있지만
#
# 당시 애비 이기붕이 이승만 사후 후계자가 없으니 이참에 자기아들을 양자로 받아들여달라고 이승만한테 그랬음
# 그리고 이승만은 어차피 양자를 두고싶어하기도했고.
#
# 근데 결국 이기붕이 자기집안을 이승만 후계로 이어받아 정통성을 인정받고싶은 욕심에 이강석 본인이 원치도않은 양자입양이 되었을수도있고
#
# 아버지한테 원한이 없을수가 없었겠지
# 애비가 자기욕심에 그렇게 본인의사와는 무관하게 자기를 소모품 갖다쓰듯이 일 저질러버리는데 누가 그런 애비와 자식관계를 정상적으로 볼수있겠냐
#
#
# 27번 댓글 :  댓글 잘못달았냐?이강석한테 청렴결백이니 뭐니까지 할 필요 없다고 한걸 이렇게 받아들이네
#
# 그리고 그렇게 치면 이승만이나 이기붕이나 인간성 면에선 영 좋다 하긴 힘들테고
#
#
# 28번 댓글 :  가만히있는 이승만은 뭔 죄임?이승만이 이런 내막을 모르고 이기붕한테 속아서양자로 받아들인걸수도 있는데?넌 누구한테 딜 할때 니 속마음 다 끄집어내서 다밝힘?이기붕이 말을 안했을수도있는거고 부정선거 일으킨 장본인이 이기붕이니까 앞뒤따져봐도 더 그렇겠지?그리고  청렴결백한거랑 아예 무관하다 할 수도없지않냐?신분도 군인이었고 이승만이 양자로 삼을정도로 나라에대한 애국심이 투철했을수도있고 그러기에 더 부정선거 사건을 본인이 심각하게 받아들이고 죽였을수도있지
#
#
# 29번 댓글 :  이승만이 치매걸린 것도 아니고 멍하니 있다가 뜬금없이 이기붕이 접근해서 이강석을 양자로 들어왔다는 거냐?그게 더 이상한데
#
# 거기다 청렴결백한거 치곤 파출소에서 깽판치고 경찰 두들겨팬 전력도 있는데다 서울대 법대도 빽 아니냐고 하도 말이 많아서 육사로 간거라 청렴결백은 좀 그런데
#
# 아니면 이기붕이 하도 폐물이라 이기붕에 비하면 청렴결백하다는 거냐?
#
# 그리고 저 양자입적 자체가 항렬도 법도 다 무시한 거라 해명을 어떻게 해도 글쎄다
#
#
# 30번 댓글 :  파출소깽판치고 경찰두들겨팬건 이강석사칭한놈이 그런건데?
# 좀 뭐나 제대로 알고 말해라
# 그리고 항렬도 법도 무시?ㅋㅋ
# 니가말하는 항렬이랑 법이 뭔데?
# 당시에 제정된 법이 지금까지 이어져와서 유지되고있는법은
# 국가보안법 말곤 없을거다
# 당시 친족법이 어떻게되있었는지 알고 말하면 몰라
# 민법이 언제 제정됬는진 아냐;
#
#
# 31번 댓글 :  가짜 이강석 말하는거냐?근데 그건 다른 사건으로 잡혀간거고 파출소 깽판친거 자체는 진짜 이강석이 한건데
#
# 내가 말하는 항렬과 법은 이강석은 이승만의 손자뻘이라 양자로 입적이 될 수가 없고
#
# 그 당시엔 민법은 없었고 조선시대때 내려온 관습인 장자는 양자로 못가는 법 때문에 그런건데
#
# 뭔 딴소리야 심지어 국보법도 그당시 국보법하고 아주 다른게 현재 국보법인데
#
#
# 32번 댓글 :  ㄷㄸㄷㄷㄷ
#
#
# 33번 댓글 :  옳게된 사람이었군
#
#
# 34번 댓글 :  이기붕도 조선왕족이승만은 걍 조선이씨왕족 부활이다
#
#
# 35번 댓글 :  소설가중에 정치색 드러나는 새끼치고제대로 된 소설쓰는놈 없슴그딴소설 읽는 새끼도 개돼지임
#
#
# 36번 댓글 :  말좀 똑바로 해라뭐라는건지 존나 헷갈리네 ㅅㅂ
#
#
# 37번 댓글 :  우치하 이강석 ㅇㅂ
#
#
# 38번 댓글 :  일각에서는 곽영주가 이기붕 일가를 희생양으로 삼아 사살했을 가능성도 있다고 나래이션 아저씨가 그랬음
#
#
# 39번 댓글 :  이 기붕 딱 좋다!
#
#
# 40번 댓글 :  이승만, 이기붕 둘 다 개신교였는데 자살을 했어??
#
#
# 41번 댓글 :  존나 상남자네 시발 애비뒤에숨어 나만이라도 살려달라고 하는게 보통 조셍징들의 습성인데
#
#
# 42번 댓글 :  나도 이강석이 친부모 쏘고 자기도 쏴 죽였다는거 안믿김제 3자의 소행인거 같음
#
#
# 43번 댓글 :  이기붕 저리생겼구나ㅋㅋㅋ 난 이기붕하면 야인시대에서 이기붕역할한 아저씨만 생각남ㅋㅋ 이인철씨 개그맨출신임.
#
#
# 1번 댓글 :  동게 탈출 2ㅂ
#
#
# 2번 댓글 :  어쩌라고 ㅁㅈㅎ
#
#
# 3번 댓글 :  말자아으지
#
#
# 4번 댓글 :  디저트정도로 만족해라
#
#
# 5번 댓글 :  진짜 키울맛 안나겠다
#
#
# 6번 댓글 :  ㅋㅋㅋㅋㅋㅋ울엄마가키움
#
#
# 7번 댓글 :  좃같은개새끼를 어디공용벤치에 처올리냐?김치년하고다를바가뭐노?
#
#
# 8번 댓글 :  샤워시켯다이기야
#
#
# 9번 댓글 :  말티즈 털빠짐 어떠냐
#
#
# 10번 댓글 :  털 많이 빠짐
#
#
# 11번 댓글 :  털 덜 빠지는건 푸들,비숑프리제 뿐임?
#
#
# 12번 댓글 :  ㅇㅇ
#
#
# 13번 댓글 :  ㄹㅇ 개패고싶은 상이다
#
#
# 14번 댓글 :  개는 사람같이 의자 위에 올리는거아니다. 오직 허용되는건 식탁뿐이다.
#
#
# 15번 댓글 :  부추랑같이 개걸스럽게 먹고싶다
#
#
# 16번 댓글 :  물에 된장 풀어놔라!
#
#
# 17번 댓글 :  얼마나 관리를 안해줬으면 유기견같냐
#
#
# 18번 댓글 :  아닌것 같은데?ㅋ
#
#
# 19번 댓글 :  Pop that pussy!
#
#
# 20번 댓글 :  치아관리 잘해줘라..충치생기면 개고생한다
#
#
# 21번 댓글 :  ㅡ,.ㅡ 왜키우냐
#
#
# 22번 댓글 :  버리고가게?
#
#
# 23번 댓글 :  승질머리 존나 더럽게 생겼네 목줄 안 차서 ㅁㅈㅎ
#
#
# 24번 댓글 :  존나 착하다. 모르는사람한테도 막 엥긴다
#
#
# 25번 댓글 :  창녀같노
#
#
# 26번 댓글 :  씨발련아
# 1번 댓글 :  원래 차 번호 바꾸고 싶다고 막 바꿀수있는게 아님
#
# 구형 번호판을 신형으로 바꾸거나(지역->전국번호, 이번처럼 두자리->세자리)
# 명의변경 하고 한번
# 분실이나 도난시
# 정도만 바꿔줌
#
#
# 2번 댓글 :  역시 근본이 없는 나라라 그런가 옆나라 보다 뭐가 철저한게 없네
#
#
# 3번 댓글 :  극혐;; 차나리 세금내는 지역명 명기 시키는게 나음ㅁㅈㅎ
#
#
# 4번 댓글 :  5600만개가 모자라서 5억6000만개가된거임 근데 차없는 어린애나 가난충들도 많은데 그많은숫자 어따쓴거임? 5000만따리 국가가?
#
#
# 5번 댓글 :  말소된 번호도 몇년 전 까지는 재사용 못했었음그래서 말소된지 3년 초과된 일부 번호를 재사용 병행해도답이 안나와서 한자리 늘린거
#
#
# 6번 댓글 :  아 그렇군 하긴 말소된것도 보존해야할 필요가 있긴하지
#
#
# 7번 댓글 :  진짜 지역 좀 넣지 시발
#
#
# 8번 댓글 :  주차장 기기가 8자리 번호판 인식 못한다던데새차 뽑지않는이상 바꿀이유가 잇긴하노?
#
#
# 9번 댓글 :  주차장 기기가 인식 못하면 좋지 뭐
#
#
# 10번 댓글 :  차단기도 안 올라감 ㅋㅋ
#
#
# 11번 댓글 :  오 나 번호판 개더러운데 바꿔볼까 새걸로
#
#
# 12번 댓글 :  일제신차인데 저번호판이면 테러한다더라 ㅋㅋㅋㅋㅋㅋㅋ
#
#
# 13번 댓글 :  지역을 다시 넣어야지 즌라도 거르지 니미
#
#
# 14번 댓글 :  전라 20누 4885 이렇게좀홍어감별앙망
#
#
# 15번 댓글 :  그냥 영국식 번호판이랑 다를바가 없네 ... 태극기라도 넣던가 지역 등록지라도 넣던가 하지 ...
#
#
# 1번 댓글 :  너도그렇노
#
#
# 2번 댓글 :  어디서 본글같아서 ㅁㅈㅎ
#
#
# 3번 댓글 :  인터넷 생활 몇년 하다보면 소스가 돌고돈다는걸 깨닫지.
#
# 2011~14년 사이가 모든 사이트들 다 재밌었는데
#
# 어느순간 신규 소스자체가 사라진 느낌임.
#
# 내 개인적인 생각으론 각 커뮤니티 a급 똥싸개들이
#
# 다 현실사회에서 열심히 살고 있지 않나 싶음.
#
#
# 4번 댓글 :  ㄹㅇ...
# ㅇㅂ 관서원교나 열혈강호.. 디씨에 고정 복붙 댓글 달던 그런 놈들 다 어디로 갔을까..
# 사람은 똥이야 똥! 히히! 오줌발싸~
#
#
# 5번 댓글 :  그럼 여자친구 아버지랑 사귀면되겠네여자친구아버지랑하면 여자친구얼굴떠오를거아냐
#
#
# 6번 댓글 :  가족이랑 떡치는거 아니다.
#
#
# 7번 댓글 :  난 이딴소리 하는놈들 참 이해가 안가
#
# 그럼 마누라는 남편말고 옆집새끼랑 떡치리?
#
#
# 8번 댓글 :  개꼴린다...
#
#
# 9번 댓글 :  자네 이제 뒤로 한번 해보는게 어떻겠나
#
#
# 10번 댓글 :  ㅇㅇ 내 마누라 엄마랑 똑같이생김
#
#
# 11번 댓글 :  마 니 게이가?
#
#
# 12번 댓글 :  장인+장인딸+일게이=장애인
#
#
# 13번 댓글 :  다비슷하게생긴거지 여동생이나 누나보고 자지가선다는건 이해가안됨
#
#
# 14번 댓글 :  장인 볼때마다 서는 부작용이 오는 나는 어떡하냐??
#
#
# 15번 댓글 :  이런댓글보는맛에 일베온다ㅋㅋㅋㅋ 정상적인새끼들만보다가 일베오면 뮤턴트의세계로진입한느낌ㅋㅋㅋ
#
#
# 16번 댓글 :  멀고도 험한 애국보수의 길...
#
#
# 17번 댓글 :  그거 있음 ㅇㅇ
#
#
# 18번 댓글 :  여친도 다르지 않을껄?
#
#
# 19번 댓글 :  장인 제거하면 해결되는 문제같은데시베리아로 이사가라해
#
#
# 20번 댓글 :  나는 그런거 좋던데 부모님 보고오면 할때 여친부모님 생각하면서 고이잘기른딸  내가 잘 먹습니다 ㅋㅋㅋㅋㅋㅋㅋㅋ 이러고 생각하면서 하면 풀발댐
#
#
# 21번 댓글 :  성형충은 아니네 안심하고 질싸해라
#
#
# 22번 댓글 :  니 여친입장에서  니가  니 엄마 닮아서 떡치고 싶은 생각이 싹 달아났다면  너는 그 년보고 무슨 생각이 들까
#
#
# 23번 댓글 :  장인어른 성형시켜드려라.
#
#
# 24번 댓글 :  최태민도 박정희 각하 떠올라서 힘들었겠네?
#
#
# 25번 댓글 :  레카 고우시다
#
#
# 26번 댓글 :  우자키양 ㅇㅂ
#
#
# 27번 댓글 :  장인어른죽이고 유기하면되잖아
#
#
# 28번 댓글 :  내가 이래서 친오빠나 남동생 있는 여자는아무리 예뻐도 믿고 거른다.성관계 맺을때마다 오누이 오빠얼굴, 남동생얼굴 떠오름.그리고 여자 배에서 남녀 둘다 출생했다는게 좋은게 아니다.외동딸, 자매는 가치가 뛰어나지만 거기서 더러운 남캐 하나뜬금없이 낳아놓으면 순식간에 딸의 가치가 폭락한다.
#
#
# 29번 댓글 :  난 반댄데.. 남자형제 없이 외동딸이나 딸만 있는 집 애들 거른다.
#
# 오빠한테 개기다 쳐맞아 보지 않은년들은 남자에 대한 공포나 배려심이 눈꼽만큼도 없다
#
#
# 30번 댓글 :  ㄹㅇ 정웅인 딸들 정웅인을 예쁘게 닮았던데, 나중에 딸래미들 남친, 남편들은 볼떄마다 정웅인 떠오를듯 ㅋㅋㅋㅋㅋ
#
#
# 31번 댓글 :  그거  심리적으로  크다문제가
#
#
# 32번 댓글 :  ㄹㅇ 전여친 엄마 얼굴한번 보니까전여친이랑 스킨쉽할때마다 걔네 엄마 얼굴 오버랩되더라
#
#
# 33번 댓글 :  모녀덮밥이네 개부럽다
#
#
# 34번 댓글 :  장인이랑 한번해라 그럼 해결됨
#
#
# 35번 댓글 :  했냐 니는
#
#
# 36번 댓글 :  마! 그걸 극복해야 되!
#
#
# 37번 댓글 :  나도 비슷한 경험있다 친구 여동생이랑 떡친적있는데 친구 볼때마다 발기함..
#
#
# 38번 댓글 :  별걸 다 갖고 지랄들허네느그들은 떡칠때 그런상상이나 할 여유가 있더냐이거 조루나 될까봐 걱정이지 별거 다 생각해서 떡떡떡하노
#
#
# 39번 댓글 :  자네 오늘은 후장에다 해주겟나
#
#
# 40번 댓글 :  딸이 엄마닮는건 흔치않나?
#
#
# 41번 댓글 :  장모랑 무슨 모녀덮밥할려고 생각했냐 그럼?
#
#
# 42번 댓글 :  내 손녀딸도 이 할애비를 닮았어요~~
#
#
# 43번 댓글 :  븅신뒤집어서 뒤치기하면되지ㅉㅉㅉ머릿끄댕이도 함 잡아땡겨주고 마!! 그렇게 하란말이야 으이?!
#
#
# 44번 댓글 :  우자키 ㅇㅂ
#
#
# 45번 댓글 :  나는 여친하고 ㅅㅅ 할때 무조건 딴여자 상상하고 눈 ㅊ대한 안마주침
#
#
# 1번 댓글 :  나 쟤들  시청자인데   다케시마는 갓본땅 하자 그냥
#
#
# 2번 댓글 :  일본에 살면 남자애가 차별받을듯ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 3번 댓글 :  독도나 울릉도 내준다고 뭐 달라질게 있나 ?  함박도 는 왜  내줌 ?  울릉도 주민도  일본국적 준다면 얼씨구나 함
#
#
# 4번 댓글 :  굳이 갈때 많은데 울릉도를..
#
#
# 5번 댓글 :  인종차별하는 싶세기들
#
#
# 6번 댓글 :  저기 못생긴 여자가 스시녀라고? 음...
#
#
# 7번 댓글 :  어휴 시발 좆반도 수준 아니 시발 지들 좆대로 승선거부를 하냐?이게 인종차별이지 다른게 인종차별이노 좆미개한 씹새끼들은 민찌기가 답이다
#
#
# 8번 댓글 :  와우 저렇게 대놓고 차별을 할 줄이야. 반일교육의 문제점이 개돼지들은 선을 모른다는 거임.
#
#
# 9번 댓글 :  울"등"도는 어디있는 나라길래 "입국"이 안되냐?
#
#
# 10번 댓글 :  일본새끼들 독도와서 지랄할까봐 울등도만 그런거 아냐 씨발 병신새끼들아. 전국  울릉도 빼고 일본인이 못가는데 있냐?
#
#
# 11번 댓글 :  입국거부가 아니라 승선거부다
#
#
# 12번 댓글 :  울능도 안가길 잘한거다...거기 들어가서 무슨 개고생을 할려고...울능도 바가지 불친절 유명하잖아?  경북판 절라도 아니노?
#
#
# 1번 댓글 :  역시 시장님 안목이 좋으시네 젊은 여자만 양쪽에 끼고 좋구만요!
#
#
# 2번 댓글 :  회사 회식하고 비슷하네 한잔 걸치면 로테이션 한다. 저 바닥의 매너야 ㅎㅎ
#
#
# 3번 댓글 :  오 ㅏ 씨발 그런것두 있냐 오 ㅏ
#
#
# 4번 댓글 :  .
#
#
# 5번 댓글 :  wwq
#
#
# 6번 댓글 :  왼쪽 여자 이쁜 것 같다
#
#
# 7번 댓글 :  솔직히 남자로서 이해할수 있는 부분이라별로 욕하고 싶지는 않다만.......그래도멀리 보낸 아주머니 두분을 보니 내 가슴이 다 아프다.......저분들도 누군가의 딸 누군가의 부인 누군가의 엄마일텐데 ㅜㅜ
#
#
# 8번 댓글 :  오거돈이 '박정희'했네
#
#
# 9번 댓글 :  너 일베하는 이유가 뭐냐?
#
#
# 10번 댓글 :  일베선배를보면 충성부터외쳐라 군기가빠져갖고
#
#
# 11번 댓글 :  어디 하자있냐?
#
#
# 12번 댓글 :  이따 집합해라
#
#
# 13번 댓글 :  저기서 만약 한잔빨고 모텔끌고가서 혼외섹스했으면 다이쥬의 정신 ㅆㅅㅌㅊ?
#
#
# 14번 댓글 :  우리 법인장 생각나네 여자직원들 다 아줌만대도 지옆에 끼고 앉드만  꼰대 새끼들 진짜
#
#
# 15번 댓글 :  남이 하면 권위주의내가하면  여권신장내로남불 더민당 시장답네
#
#
# 16번 댓글 :  거돈이형 성악 ㅈㄴ잘함
#
#
# 17번 댓글 :  ㅈㅈㅂ
#
#
# 18번 댓글 :  ㅋㅋㅋㅋ오거돈 존나 웃기네 ㅋㅋㅋㅋ그와중에 나이든 여자 저 멀리 보내는거 보소 ㅋㅋㅋㅋ ㅅㅂ존나  여자 늙어서 서럽겠다 ㅅㅂ ㅋㅋㅋ
#
#
# 19번 댓글 :  ㅋㅋ
#
#
# 20번 댓글 :  섹스
#
#
# 21번 댓글 :  그 와중에 아주매미들은 다른 테이블 구석에 짱박혔네ㅋㅋ
#
#
# 22번 댓글 :  ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 23번 댓글 :  축협다녔었는데  회식하면   조합장이랑  같이  않앉을려고  다피한다내가볼땐  짬좀있는새끼들  눈치까고  피해앉았고  여직원들  늦게와서  착석한걸로  보인다
#
#
# 24번 댓글 :  다 이쁘네
#
#
# 25번 댓글 :  최태민 좋아하던 닭 생각나네
#
#
# 26번 댓글 :  시발 나도 일할때 계장새끼 날밀고 옆에여자앉히더라 미친놈 개꼰대새끼더라
#
#
# 27번 댓글 :  거돈이 백제 의자왕이노 ㅋㅋ
#
#
# 28번 댓글 :  ㅈㅈㅂ ㅁㅈㅎ
#
#
# 29번 댓글 :  바둑에서 저 포진은 잡아먹힌거 아니냐? 오거돈 젊은 여자들한테 잡아먹힌겨?
#
#
# 30번 댓글 :  오거돈이 어떻게 586이냐 븅시나 70넘은틀딱인데
#
#
# 31번 댓글 :  전에 회사다닐때 회식하면 소장도 꼭 자기테이블에는 안내랑 경리 앉히더라ㅋㅋ이해는하는데 뭐
#
#
# 32번 댓글 :  같은걸 몇번이나 보냐ㅅㅂ
#
#
# 33번 댓글 :  개돼지들 페미들은 공산주의 국가가 되면 노예로 전략하는걸모름
#
#
# 34번 댓글 :  저 여자들은 뭐냐?  유니폼 입었는데 ?
#
#
# 35번 댓글 :  그게 꼰대랑 대체 뭔상관이냐 ?ㅁㅈㅎ
#
#
# 36번 댓글 :  갓산  오거돈 !
#
#
# 37번 댓글 :  아줌마는 안껴줬네ㅋㅋ
#
#
# 38번 댓글 :  회식때 상사들이 여부하직원 마니 따먹냐???
#
#
# 39번 댓글 :  ㅗ
#
#
# 40번 댓글 :  정육점 이름이냐?
#
#
# 1번 댓글 :  핑클보단 SES가 더 존예급임
#
#
# 2번 댓글 :  젊었을때 몸을..
#
#
# 3번 댓글 :  잘 씻자
#
#
# 4번 댓글 :  넷이 친하지도 않딘면서, 왜 다시 뭉친 거지? 딱 봐도 어색해 보이던데
#
#
# 5번 댓글 :  핑클 모인거?임
#
#
# 6번 댓글 :  돈이지 뭐겠냐 ㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 7번 댓글 :  가장 흔한 염색체 질환은 2개여야 할 21번 염색체가 3개인 다운 증후군이다. 대체로 미간이 넓고 코가 낮으며, 지능이 다소 떨어진다. 특히 이 병은 임신부 나이가 많을수록 발생률도 증가한다. 40대 임신부의 경우 20대보다 다운 증후군 아이를 출산할 가능성이 15~20배 높다. 산부인과에서 35세 이후 임신한 여성을 고령 산모로 분류해 산전 염색체 검사를 하는 이유다.
#
#
# 8번 댓글 :  가장 흔한 염색체 질환은 2개여야 할 21번 염색체가 3개인 다운 증후군이다. 대체로 미간이 넓고 코가 낮으며, 지능이 다소 떨어진다. 특히 이 병은 임신부 나이가 많을수록 발생률도 증가한다. 40대 임신부의 경우 20대보다 다운 증후군 아이를 출산할 가능성이 15~20배 높다. 산부인과에서 35세 이후 임신한 여성을 고령 산모로 분류해 산전 염색체 검사를 하는 이유다.
#
#
# 9번 댓글 :  가장 흔한 염색체 질환은 2개여야 할 21번 염색체가 3개인 다운 증후군이다. 미간이 넓고 코가 낮으며, 지능이 다소 떨어진다. 특히 이 병은 임신부 나이가 많을수록 발생률도 증가한다. 40대 임신부의 경우 20대보다 다운 증후군 아이를 출산할 가능성이 15~20배 높다. 산부인과에서 35세 이후 임신한 여성을 고령 산모로 분류해 산전 염색체 검사를 하는 이유다.
#
#
# 10번 댓글 :  이효리는 왜 요즘 화장 안하고 나오냐?쌩얼로 나오는거 같던데
#
#
# 11번 댓글 :  못생기면 살기힘든세상인대이효리 생각깊노
#
#
# 12번 댓글 :  이효리는 왜 갑자기 채식한다고 호들갑이냐?? 휴게소에서 짬뽕 먹을때도 지혼자만 고기 빼돌라 하질 않나 그러면서 생선은 잘 처먹고.유튜브에 패밀리가 떴다 있길래 보니깐 그때 당시는 또 삼겹살 잘 처먹네
#
#
# 13번 댓글 :  그냥 늙어서 그런거지 뭐 변명은...
#
#
# 14번 댓글 :  이효리 닮아도 그닥....
#
#
# 15번 댓글 :  아들 낳으면 봊됨이효리 당신이나 신랑이나그나물에 그밥
#
#
# 16번 댓글 :  근데 보통 아는게 첫째가 딸이면 아빠를 닮는다는거 진짜 신빙성있는말임??
#
#
# 17번 댓글 :  http://m.ilbe.com/view/10918768077
#
#
# 18번 댓글 :  환경운동 잘할것 같이 생겼다.
#
#
# 19번 댓글 :  못 낳는게 아니고?
#
#
# 20번 댓글 :  이효리가 저렇게 될줄은 진짜 ㄷ
#
#
# 1번 댓글 :  저게 대한민국 20대 병신새끼들의 현실임
#
#
# 2번 댓글 :  와, 누나한테 누나팬티딸 치는 사진 보낼 수 있는 사람이 있다니..
#
#
# 3번 댓글 :  누나가 꼴림?
#
#
# 4번 댓글 :  아 그냥 여자팬티니까 딴여자상상하며 치는거임?
#
#
# 5번 댓글 :  캡쳐했고 아이피 땄으니 너네집가서 폭로할거임 ㅅㄱ
#
#
# 6번 댓글 :  내 후장 빨아봐
#
#
# 7번 댓글 :  험하다...애국 보수의 길은...
#
#
# 8번 댓글 :  저런행동 했다고 발정?곀어보신 누나인듯
#
#
# 9번 댓글 :  누나가 보살이네
#
#
# 10번 댓글 :  후기없냐?
#
#
# 11번 댓글 :  여러분 비릉내나는 낚게로 오십셔~
#
#
# 12번 댓글 :  소름돋네
#
#
# 1번 댓글 :  보수도 진보도 아닌 중도입니다이렇게 말한다좌빨사장이라면 널 좌빨을 만들려고 입사시킬 것이고보수사장이라면 반대로 입사시킴중도라고 말했는데 퇴출당했다면 골수좌빨사장일 것임
#
#
# 2번 댓글 :  근데 이 질문이 합불을 가르는 크리티컬한 질문이 아니고 그냥 뽑앗을때 어떻게 굴려먹을지 사용하는 질문아님?만약에 사장이 진보라면 보수라 대답하고 떨어지는게 낫고사장이 보수면 보수라서 어드벤티지 잇을테니무적권 보수라고 대답하는게 나음
#
#
# 3번 댓글 :  호오 보수라 말이지?임금 적게 줘도 의리 하면 보수니까 이해 하겠지막말과 고된 노동과 위험한 일만 시켜도의리하면 보수니까 이해하겠구먼으하하하
#
#
# 4번 댓글 :  이게 좌좀들의 병신논리라는말이지. 그렇게 임금평등 부자증세 외치면서 지들하고 다른편인놈들은 돈 적게 받아도된다고 말하는 뱡신같은 이중성 ㅉㅉ. 패션좌파새끼들
#
#
# 5번 댓글 :  ㅋㅋ 그럼 좌좀들은 경부고속도로 쓰면 안되건네 ㅋ
#
# 존나 문재인식 사고 수듄
#
#
# 6번 댓글 :  젊은이들  보수없다고 ? ㅋㅋ 보수진보 프레임 누가 만든거노. 개좃같네. 좌파새끼들이 누가봐도 보수인데 용어혼란전술의 확실한 예시구만.
#
#
# 7번 댓글 :  회사 오너는 보수일 확률이 더 높다. 우리 회사사장도 맨날문재인 욕 했다.
#
#
# 8번 댓글 :  사장 오너들은 다 보수야 근데 전라도 놈들은 보수적이여도 투표는 민주당한테 주지
#
#
# 9번 댓글 :  좌파정권하에서 정치성향 물어보는 우파가 있을까?더군다나 수도권에는 호남자영업자가 얼마나많은데
#
#
# 10번 댓글 :  이딴 주작을 믿는다니
#
#
# 11번 댓글 :  그니까...조국같은 놈이 법무장관후보 되겠다가 깝칠만한 환경
#
#
# 12번 댓글 :  근데 기업총수들 윗대갈들은 거의다 보수다80년대 학번도 그러하다정규재tv 이런거 봄
#
#
# 13번 댓글 :  회사는 보통 보수를 더 좋아하겠지. 좌빨 새끼들 허구헌날 노조만들어서 파업하고 진상부리는데 좋아하겠노
#
#
# 14번 댓글 :  그런걸 물어보시는 면접관님 고향이 혹시?
#
#
# 15번 댓글 :  다음부터는 진보우파라고 해라.
#
#
# 16번 댓글 :  에네르깊ᆢ
#
#
# 17번 댓글 :  ㅋㅋㅋㅋㅋㅋ 뜬금없노
#
#
# 18번 댓글 :  사장급은 좌빨 드물음
#
#
# 19번 댓글 :  그럴때는 지금 정당중에 누가 진보고 누가 보수냐고 되 물었어야지면접관이 민주당이 진보고 한국당이 보수다 했으면 100프로 좌빨회사고그냥 당 떠나서 너의 정치성향이 궁금 한거다 했으면 당연히 진보죠 그런데 좌파냐 우파냐로 안 묻고 진보냐 보수냐 묻는거 보니 사장이 홍어네지금 대한민국에 진보가 어딧고 보수가 어딧냐공산주의와 민주주의만 있다
#
#
# 20번 댓글 :  북조선인민민주공화국?
#
#
# 21번 댓글 :  머가부끄럽노
#
#
# 22번 댓글 :  비행기 타면 가끔 조선일보 본다고 눈치 주는 사람들도 있고"젊은 총각이 조선일보를 보네?" 이렇게 직접 묻는 사람도 있음.
#
#
# 23번 댓글 :  와 ㅇㄱㄹㅇ
#
# 나만 당한게 아니었노 ㅋㅋㅋㅋㅋ
#
#
# 24번 댓글 :  물어본거보니 사장이 좌파인듯
#
#
# 25번 댓글 :  아들 ~~엄마는 아들 항상 믿어올해도 벌써 9월달이야..취업 준비 잘하고 있지??엄마 친구 아들들은 벌써 아기도 가졌더라 ㅎㅎ나이도 30대 중반인데 이제 그만 취업 하는게 좋을꺼 같어~사랑해 아들
#
#
# 26번 댓글 :  뭐래  병신아
# 인터넷 이제 깔았냐
#
#
# 27번 댓글 :  엄마 친구 아들들은 벌써 아기도 가졌더라 ㅎㅎ 이건 빼
#
# 좆병신 문재앙 국가에서 노예됐네 하고 공중제비 돈다
#
#
# 28번 댓글 :  찐따냄새 풀풀
#
#
# 29번 댓글 :  합격하면 인증하라 이기야
#
#
# 30번 댓글 :  좌빨들 드글대는 좃소가서 뭐할라고? 잘했다 이기 알아서 뽑것지 뭘
#
#
# 31번 댓글 :  사장들 좌빨같이 생겨도 우파던데.나도 정치성향 보수보이니깐 열라 좋아하던데ㅋ
#
#
# 32번 댓글 :  잘가세요
#
#
# 33번 댓글 :  합격!!!!!!!!!!!!!!!
#
#
# 34번 댓글 :  그럴때는 약간 보수쪽에 가까운 중도라고 이야기해야지 밥먹고 살기 싫냐
#
#
# 35번 댓글 :  중도보수가 정답이지
#
#
# 36번 댓글 :  걱정마라. 중견기업 임원진면접 본적있는데 대놓고 주52시간근무 까더라
#
#
# 37번 댓글 :  보수 ㅋㅋㅋㅋㅋㅋ 일베한다고 개나소나 보수냐?빨렙이면 인정한다 왜냐 빨렙엔 분탕 거의 없다(진짜 없음, 짜и이 빼고) 일단 넌 씹쪼렙이라 인정못함
#
#
# 38번 댓글 :  면접관 전라도일 확률 51.8%
#
#
# 39번 댓글 :  사장이 놀란 거 보니  너 합격이다 축하한다 게이야꽁구레츄레이션
#
#
# 40번 댓글 :  좌파 우파로 이야기해라 다음엔
#
#
# 41번 댓글 :  홍어사장도 홍어 안뽑는다
#
#
# 42번 댓글 :  2017년도에 면접봤는데 광화문에 촛불집회하길래 어떻게 생각하내 묻길래 태극기흔들러가야된다고 말했더니 씩 웃음.그리고 광탈 씨발년
#
#
# 43번 댓글 :  젊은애들은 죄다 좌빨아니냐 우파를 골라 뽑으려는거야
#
#
# 44번 댓글 :  대기업 맨날 떨어지던놈 존경하는인물에 박정희적었더니 바로 합격했단다 써먹어보도록
#
#
# 45번 댓글 :  고향이 홍어일 가능성도 큰데 베충쿤들은 보수라고만 단정짓노 ㅋㅋ
#
#
# 46번 댓글 :  우리 애비같은 좆소면 바로 광탈한다
# 1번 댓글 :  아 그러네 미안미안 작성자한테 미안하다고 좀 전해줘...쑥스러워서...
#
#
# 2번 댓글 :  죽어그냥 ㅋㅋㅋㅋ
#
#
# 3번 댓글 :  뿌잉
#
#
# 4번 댓글 :  ㅗㅜㅏ
#
#
# 5번 댓글 :  와ㅜ이건 첨보네. 멋지다 ㅇㅂ
#
#
# 1번 댓글 :  양놈 배우들은 거의다 수술한거던데..
#
#
# 2번 댓글 :  농구잘 못하는 흑인 만나면 흑인 농구실력에대한 오해 글싸겄네...
#
#
# 3번 댓글 :  동양인중에선 툭출나게 큰놈니 없음
#
#
# 4번 댓글 :  184 84 18
#
# 시원하게 뚫어줄까?
#
#
# 5번 댓글 :  저욧
#
#
# 6번 댓글 :  노발이잖아
#
#
# 7번 댓글 :  만져도 봤냐?
#
#
# 8번 댓글 :  확대기 하이드로맥스 사서 써볼려는데 효과있을까
#
#
# 9번 댓글 :  로마 조각상만 봐듀 별다를게없는거 알잖아
#
#
# 10번 댓글 :  아그리빠?
# 다비드?
# 아폴로?
#
#
# 11번 댓글 :  닥ㅊ
#
#
# 12번 댓글 :  닥쳐라!자쥐의 완성은 얼굴이다
#
#
# 13번 댓글 :  흑자지는 순대임
#
#
# 14번 댓글 :  내가 이태원 헬스클럽 다녔었는데 흑인 아랍애들 사워 할때 보니 흑인도 한국인 평상위만 하고 가끔 존나 큰 새끼들이 있더라 백인도 그렇고 아랍애들도
#
#
# 15번 댓글 :  이 얼굴이면 자지 6.9라도 여자들 질질 싸고 난리난다
#
#
# 16번 댓글 :  임시완선에서 정리가능
#
#
# 17번 댓글 :  시완이니?
#
#
# 18번 댓글 :  그냥 붕장어라 보면 된다
#
#
# 19번 댓글 :  흑인자지 하나보고 일반화시키노 ㅋㅋ ㅁㅈㅎ
#
#
# 20번 댓글 :  여사친중에 서로 섹드립 존나 하는 한때 클럽에 미친년 있는데흑인이랑 두번 해봤는데 그 이후로 흑인이랑은 절대 안한다더라 굵기도 그렇고 꼬추가 자궁벽 계속 때려서 아프다고참고로 나도 귀두만큼은 흑인보다 클 자신있다고 이빨존나 까니까 장난으로 함 보자길래 진지빨고 평가해달라고 벗어서 보여준적도 있음섹파아님
#
#
# 21번 댓글 :  니가 본애가 작은애일수도 있다우리나라 남자도 20넘들애들 많다
#
#
# 22번 댓글 :  흑자는 밀도가 떨어져. 강직도라고도 하지?작지만 딴딴한 신토불이가 촥오
#
#
# 23번 댓글 :  영어로 자라좃 = Grower penis그 반대는 = Shower Penis 자라좃이라 느무느무 억울하다 이기야. 세워서 보여줄수도 없고
#
#
# 24번 댓글 :  이건 글로쓸필요도 없이 상식아니냐흑인중에서도 좆이 ㅈㄴ 큰편이니까 av배우됬겠지야동보고 흑인좆 다 크다고생각하는건 원빈보고 한국남자들 다 원빈처럼 생겼겠다고 생각하는 수준임
#
#
# 25번 댓글 :  나는 흑인이면 다큰줄 알았던게 드래곤힐스파에서 흑인 꼬추 첨봤는데 진짜 노발 15센치 나오겠더라
#
#
# 26번 댓글 :  길이는 어느정도되고 딱딱해야됨
#
#
# 27번 댓글 :  난 흐긴이 다큰줄
#
#
# 28번 댓글 :  일베만 오면 180기본에 좆은 15가 최소라던데 사실인가요?
#
#
# 29번 댓글 :  목욕탕 이런데서 비교하는건 의미가 전혀 없음발기된 상태가 중요하지
#
#
# 30번 댓글 :  금동이는 잘 아는데몽동이는 누고
#
#
# 1번 댓글 :  어제 일베 온글을 그대로 올리네 ㅁㅈㅎ
#
#
# 2번 댓글 :  어제본거 ㅁㅈㅎ
#
#
# 3번 댓글 :  원숭이가 진화를 했더니 인간이 된게 아니라, 원숭이의 진화형태 or 더 발전된 형태가 인간인거다. 개독놈들 원숭이 뱃속에서 갑자기 인간이 태어나는게 말이 되냐고 묻는데 진화론은 어떤생물이 진화한 생물을 낳는다는 뜻이 아니다. 인류의 시작은 돌이 아니라 철이다. 돌을 이용한건 고대원숭이의 한 종류이자 인간을 닮은 짐승일뿐. 진화론 똑띠 이해하고 주장하길 바란다.
#
#
# 4번 댓글 :  인간의 현재모습이 발전된 형태라는 건 니 망상이고 진화론 관련 책을 좀 읽어라 어떤 새끼도 지금이 존나 진보된 발달한 형태다 이지랄 안 함
#
#
# 5번 댓글 :  그럼 퇴보임? 병신아 ㅋㅋ
#
#
# 6번 댓글 :  그와중에 잘생겼노ㅋㅋ일베충보단 낫네
#
#
# 7번 댓글 :  지적으로 생겼다
#
#
# 8번 댓글 :  나중엔 쟤들도 촛불 들고 나옴
#
#
# 9번 댓글 :  우리 선조들이 만든 원형돌칼은 사냥용 무기였다
#
#
# 10번 댓글 :  ㅈㅈㅂ
#
#
# 11번 댓글 :  퍼오려면 제대로 알고 좀 퍼오지 쟤네보다 보노보 챔핀지가 훨씬 앞선다 도구 사용 o 구석기 도구 만듬 o 불사용 함 심지어 라이터 성냥주면 지들이 불켜서 음식 익혀 먹는다 뭔 시발 최초의 구석기 드립이고 ㅋㅋㅋㅋㅋㅋㅋㅋ그리고 원숭이랑 침팬지는 비교불가다 그냥 침팬지압승이야 최근에 집에서 키우던 침팬지 스마트폰 사용 인간의 말을 알아듣고 210가지의 그림으로 언어를 표현하는 침팬지도 있다 좋아하는말이 열쇠로 사육장 문을 열어주면 밖에 나가서 놀 수 있으니 좋다였다 번외 범고래도 이와 버금가는 수준의 능력을 구사할 수 있고 초음파를 통한 고유언어가 있다
#
#
# 12번 댓글 :  쟤들이 철기문명 수준에 도달하게 되면 인간은 태양계 벗어나 있음
#
#
# 13번 댓글 :  진짜 진화론 한새끼들 대가릴 오함마로 다깨야함
#
#
# 14번 댓글 :  혹성탈출 꿀잼
#
#
# 1번 댓글 :  근데 페르몬 향수가 효능이 있긴 한건가?
#
#
# 1번 댓글 :  일매출20이면 주방에 둘씩이나필요하냐?
#
#
# 2번 댓글 :  금순씨랑 쎅쓰 했냐 안했냐 그것만 말해
#
#
# 3번 댓글 :  이새끼 기만자임 사실 사장게이임
#
#
# 4번 댓글 :  김금순씨 불체자이면 오늘이 마지막이겠군
#
#
# 5번 댓글 :  니 ㅈㅉ 이가?
#
#
# 6번 댓글 :  한달 600이면 200씩 사이좋게 3띵하면되나? ㅋㅋㅋ
#
#
# 7번 댓글 :  머가리 수준 ㅠ
#
# 매출이 20이라 잖아
# 20만원에서 부가세 10% 나가고, 원재료 값 나가고, 월세 나가고,
# 공과금 나가고, 인건비 나가고 ㅋㅋㅋㅋ
#
# 근데 일하는 사람은 사장포함 셋이고
#
# 그냥 자살이 답이다 이기야
#
#
# 8번 댓글 :  꼭 이런것들이 회사 외형만보고 회사 돌려서 노동자들 고혈빨아서
#
# 사장만 잘먹고 잘사는줄앎
#
#
# 9번 댓글 :  와.. 나아는사람 하루카페매출 원래 20정도였는데(시골에서 동네장사) 문재린되고나서 10만원도 겨우나윤다함
#
#
# 10번 댓글 :  이거 사장이 건물주아닌이상 곧 망할집인데
#
#
# 11번 댓글 :  건물주여도 망함
#
# 주방 2명만써도 인건비 명당 200넘어감 달에
#
#
# 12번 댓글 :  ㅇㄱㄹㅇ
#
# ㅋ 이건 건물주도 커버못함
#
#
# 13번 댓글 :  사장이 건물주라도 망하는 매출인데
#
#
# 14번 댓글 :  조선족한테 원화유출시키는 시발개새끼 ㅁㅈㅎ
#
#
# 15번 댓글 :  중국년 머리는 감냐? 보기만해도 드럽네 ㅅㅂ
#
#
# 16번 댓글 :  조선족 아줌마소개쫌
#
#
# 17번 댓글 :  지금같은 날씨에냉면집에 일매출 20이면이게 현실적으로 가능 한거냐?문을 닿아도 벌써 이미..아울러 찬바람 냄새라도 난다면...
#
#
# 18번 댓글 :  냉면단가 300원이야ㅋㅋ
#
#
# 19번 댓글 :  조선족   니애인이가
#
#
# 20번 댓글 :  식빵 곰팡이 난거 아니냐?ㅋㅋ 저 서있는짤
#
#
# 21번 댓글 :  어쩐지 배아프네
#
#
# 22번 댓글 :  일매출20인데 사람두명 인건비는나오냐?주작아님?
#
#
# 23번 댓글 :  월600이면 2명분이랑 임대료는될듯
#
#
# 24번 댓글 :  좋은 바람이라.."더치페이하기 좋은 날씨다"생각나서ㅇㅂ
#
#
# 25번 댓글 :  건강해라
#
#
# 26번 댓글 :  요즘 넹면 20만 팔면..건물 사장꺼냐?
#
#
# 27번 댓글 :  냉면감성 ㅇㅂ
#
#
# 28번 댓글 :  성공해서 돈을 많이 벌 겁니다 내 인생도 벌써 절반이 지나갔어요
#
#
# 29번 댓글 :  금순씨 잘주냐
#
#
# 30번 댓글 :  요리에 요짜도 모르면 분식집 배달부터 시작해라물건이 어떻게 만들어지는지도 모르는 놈들이허파에 바람만 잔뜩 들어가꼬 말이야
#
#
# 31번 댓글 :  왔능가
#
#
# 32번 댓글 :  일매출 20 이면 건물주냐?
#
#
# [['보지털', '지잠털', '777777777777777222777777777777777\n777777777288888888888887777777777\n777777778888888888888888877777777\n777777788888054494088888887777777\n777777788877777277208888887777777\n777777788871884745488888887777777\n777777778072482748525488887777777\n777777777227242728817588877777777\n777777777722052548882088877777777\n777777777777722298888888880777777\n777777777720852150888888888888027\n777758888888877545277888888888888\n798888888888872277778888888888888\n588888888888874880788888888888888\n888888888888278897888888888888888\n888888888888818808888888888888888\n888888888888872888888888888888888\n888888888888882728888888888888888\n888888888888887788888888888888888', '경험치가 안오른다 빨리 수정해라', '언제 고렙 되노?얼마나 걸리노 보통?', '낄낄낄', '나도 고랩되고 싶다', '출석체크라는게 글을 올려야되는거노?', 'ㅁㅍ', '씨발놈아 나도 ㅁㅈㅎ 누르고싶다괜히 본캐 처 지워서 씨발', '난 몇년동안 2랩이냐 왜', '일베 한번 보내면 3렙 되겠네', '경험치타임좀 만들어라렙이 너무안오른다', '경험치 부스터 캐시 300무현', '하루에 200개를 몇날며칠 계속해서 만드는놈도 대단하다\n\n그쯤되면 그건 이미 열정 정도도 아니고 광기네', 'ㅂㅇㄹ', '오ㅑ시발자꾸 이게클릭되냐', '와 씨발 운매새끼들 드디어 일하네 좆같은련들아 함대줘라', '섹스', '쎅스', '씨발 렙2짜리 아이디 지웠다가다시 렙2만들라니까 좆같이 힘드노 개같은년아 2렙으로 올려라 내꺼', '추천 이 안되네 나 0렙이냐? 가입일이 몇년 인데 ㅋㅋ', '나 로그인만으로 4렙담', "ㅡㅡヽ、_ノㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅤ\nㅤㅤㅤ 'ｰ '\nㅤㅤㅤㅤㅤＯ\nㅤㅤㅤㅤㅤㅤo\nㅤㅤㅤㅤㅤㅤ 。\n………………_„-,-~''~''':::'':::':::::''::::''~\n………._,-'':::::::::::::::::::::::::::::::::::::::''-„\n………..,-'::::::::::::::::::::::::::::::::::::::::::::::|\n………,-'::::::::::::„:„„-~-~--'~-'~--~-~--~-\n……..,'::::::::::,~'': : : : : : : : : : : : : : : : : : '-|\n……..|::::::::,-': : : : : : : : - -~''''¯¯''-„: : : : :\\\n……..|::::::::|: : : : : : : : : _„„--~'''''~-„: : : : '|\n……..'|:::::::,': : : : : : :_„„-: : : : : : : : ~--„_: |'\n………|::::::|: : : „--~~'''~~''''''''-„…_..„~''''''''''''¯|\n………|:::::,':_„„-|: : :_„---~: :|''¯¯''''|: ~---„_: ||\n……..,~-,_/'': : : |: :(_ o__): : |: : : :|:(_o__): \\..|\n……../,'-,: : : : : ''-,_______,-'': :. : : : ''-„__ ___ |\n……..\\: :|: : : : : : : : : : : : : :„: : : : :-,: : : : : : \\\n………',:': : : : : : : : : : : : :,-'__: : : :_',: : : : ;: ,'\n……….'-,-': : : : : :___„-: : :'': : ¯''~~'': ': : ~--|'\n………….|: ,: : : : : : : : : : : : : : : : : : : : : :: : :|\n………….'|: \\: : : : : : : : -,„_„„-~~--~--„_: :: |\n…………..|: \\: : : : : : : : : : : :-------~: : : : : |\n…………..|: :''-,: : : : : : : : : : : : : : : : : : : : :|\n…………..',: : :''-, : : : : : : : : : : : : : : : : :: ,'\n……………| : : : : : : : : :_ : : : : : : : : : : ,-'\n……………|: : : : : : : : : : '''~--------~''\n……….„-''. '-,_: : : : : : : : : : : : : : : : : ,'\n……,-''. . . . . '''~-„_: : : : : : : : : : : : :,-'''-„", '이거 진구야?', '나도 빨리 고렙되고 싶다', 'ㅅㅂ 글올리고 싶어도 못올리잖아', '1렙이 왜 추천 ㅁㅈㅎ 못하냐 완전오바아니냐', 'ㅇㅂ', '숙지완료했다~', 'ㅅㄱ많다', 'ㅁ', '숙지', 'ㅅㄱ많음', '이새끼 퇴사안함?', '엌ㅋㅋㅋㅋ 백수 ㅊㅋ한다 엌ㅋㅋㅋㅋ 공중제비돈다이기야 엌ㅋㅋㅋㅋㅋㅋㅋㅋ', '소금쟁이랑 설명충 무슨관계?', '어쩐지', '일베 가자 ㅋㅋㅋㅋㅋ', '근데 게시글은 어떻게 올림. 존나 찾아봐도 없네', '네', '잉여력 어떻게 키우노?', '아엠어 보이', '3.0 민주화 폭탄대기중 필승!', 'ㅎㅎ', 'ㅇㅂ', 'ㅋㅋㅋㅋㅋㅋㄱㅅ'], ['떡감 어떻냐? \n\n너랑 한번 느껴 보고싶다.', '들딱인데 글을 어캐 올리는지 설명좀 해주라...............', '고생해', '좆까 씨발년아', '일간베스트저장소 베너 직원상시모집 보고 나도 취직하고 싶은 욕망이 퐉퐉 생겼는데 운영자게이야 나 취직못하냐 이기?', '근데 시발 비번 찾기왜 안되냐?\n갑자기 로그인풀렸는데 비번생각안나서 이메일찾기했는데7일만에 오냐? 미쳤노 ㅡㅡ', '나는 왜 수 개월째 추천이 안되노???', '와 진짜 망했구나', '유지 빨통 함 까라 장기적인 수익 내가 보장한다', 'ㅇㅂ가 적자면 오유같은 다른 사이트는 어떻게 운영되노', '광고', '직무유기 ㅆㅅㅌㅊ', '천조국처럼 프리미엄 레벨 서비스를 해서 한달에 2-3천원내면 광고같은거 없고 플러스로 다크모드같으거 너서 데탑에도 하약/회섹 말고 검저 스킨같은거 기능 추가해서 클린ㅇㅂ하게되는 서비스를 하던 유료서비스를 생각해맨날 광고로만 돈처먹을려고 하지말고 ㅇㅂ충들한테 직접돈벌고 기능좀 업그래이드하고 그리고 ㅇㅂ 인터패이스좀 업하자 ㅅㅂ 요새는 모니터 다 16:9이고 나같은 소수는 21:9 32:9가는데 ㅅㅂ ㅇㅂ사이트 아직도 무슨 90년데 스타일임', '너네 왜 그런식이냐맘에 안든다 좀 똑바로 좀 해라 일을 그렇게 밖에 못하냐', '틀', '빨...', '나새야 일베얼마주고 삿노? 확시원하게 까봐라...투자도 받노???', '존댓말 씹소름.... 형 왜이래? 무섭게', '너무 정게로 운지시킨다  유머로 냅둘만한데  노무하는거 아니노?  운마ㅆㅅㅋ야', '하여간 수고많다\n\n개소리 하는것들은 분탕이다생각하고\n\n걍 신경꺼라', '다시끄럽고 유지 썅년아 보밍하지말고 분탕이나 잡아라.  분탕은 모른척하고 분탕 고발하는 게이를 벤하는게 일베 맞냐? 일베의 본질은 우파 정치사이트가 맞어. 근데 일베 망하라고 개소리 찍찍하는 분탕들 왜 안잡는건데?운마가 홍어년 아니면 왜 이러는지 이해 불가함.', '그리고 모든 커뮤니티 몰락의 중심엔 보지가 있었다. 그래서 일베가 보밍을 철저하게 단속한건데 뭐 운바가 보밍하고 유튭을 개설한다고? 이거 홍어 아니고는 나올수 없는 발상이라고 ㅎ. 진심 홍어면 정정당당하게 홍밍아웃하던지. 그래야 일베의 정체성을 게이들이 오해를 안하지 ㅎ', '정게틀딱들 기사 캡쳐 한장에 일베가거나 기사 한줄찍으 ...

# %%
sum1 = 1
i = 0
j = 0

wb = Workbook()

#파일 이름을 정하고, 데이터를 넣을 시트를 활성화합니다.
sheet1 = wb.active
file_name = 'ilbe_Crawling.xlsx'

#시트의 이름을 정합니다.
sheet1.title = 'data'

#Sheet1에다 입력
sheet1 = wb.active
sheet1['A1'] = 'content'
sheet1['B1'] = 'index'

for j in range(0, len(review_list)):
    for i in range(0, len(review_list[j])):
        sum1 = sum1 + 1;
        sheet1.cell(row=sum1, column=1).value = review_list[j][i]

wb.save(filename=file_name)
